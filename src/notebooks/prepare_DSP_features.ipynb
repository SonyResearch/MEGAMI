# %%
import torch
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

#use gpu number 3 
device=torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

#file_id=6448
file_id=23114

base_path="/home/eloi/projects/project_mfm_eloi/audio_examples/TM_val/"
file_dry=os.path.join(base_path, "dry",str(file_id),"vocals.wav")
file_wet=os.path.join(base_path, "wet",str(file_id),"vocals.wav")

file_dry_fxnorm=os.path.join(base_path,"dry", str(file_id), "vocals_normalized.wav")
file_wet_fxnorm=os.path.join(base_path, "wet",str(file_id), "vocals_normalized.wav")

file_dry_fxnorm_dr=os.path.join(base_path, "dry", str(file_id), "vocals_normalized_dr.wav")
file_wet_fxnorm_dr=os.path.join(base_path, "wet",str(file_id),"vocals_normalized_dr.wav")

import soundfile as sf

print("Loading files:", file_dry, file_wet)
dry, sr = sf.read(file_dry)
print("Loading files:", file_dry, file_wet)
wet, sr = sf.read(file_wet)
print("files loaded")

#file_dry_fxnorm, sr=sf.read(file_dry_fxnorm_dr)
#file_wet_fxnorm, sr=sf.read(file_wet_fxnorm_dr)

dry=torch.from_numpy(dry.T).float().unsqueeze(0)
wet=torch.from_numpy(wet.T).float().unsqueeze(0)

#dry_fxnorm=torch.from_numpy(file_dry_fxnorm.T).float().unsqueeze(0)

dry=dry.mean(dim=1, keepdim=True)

#dry_fxnorm=torch.from_numpy(file_dry_fxnorm.T).float().unsqueeze(0)


start_t=15*sr
segment_length = 524288
wet_segment = wet[...,start_t:start_t + segment_length]


import pyloudnorm as pyln
meter = pyln.Meter(sr)
normaliser = lambda x: pyln.normalize.loudness(
    x, meter.integrated_loudness(x), -18.0
)

print("dry", dry.shape, dry.min(), dry.max())

dry = torch.from_numpy(normaliser(dry.numpy().T).T).float().to(device)
#wet = torch.from_numpy(normaliser(wet.numpy().T).T).float().to(device)
#dry_fxnorm = torch.from_numpy(normaliser(dry_fxnorm.numpy().T).T).float().to(device)


print("dry", dry.shape,dry.min(), dry.max())
dry_segment = dry[...,start_t:start_t + segment_length]


from IPython.display import Audio

Audio(dry_segment[0].cpu().numpy(), rate=sr, normalize=False)
#Audio(wet_segment[0].cpu().numpy(), rate=sr, normalize=True)
# Out:
# Using device: cuda
# Loading files: /home/eloi/projects/project_mfm_eloi/audio_examples/TM_val/dry/23114/vocals.wav /home/eloi/projects/project_mfm_eloi/audio_examples/TM_val/wet/23114/vocals.wav
# Loading files: /home/eloi/projects/project_mfm_eloi/audio_examples/TM_val/dry/23114/vocals.wav /home/eloi/projects/project_mfm_eloi/audio_examples/TM_val/wet/23114/vocals.wav
# files loaded
# dry torch.Size([1, 1, 7014686]) tensor(-0.7464) tensor(0.7499)
# dry torch.Size([1, 1, 7014686]) tensor(-0.8735, device='cuda:0') tensor(0.8776, device='cuda:0')
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from typing import List
from utils.ITOMaster_loss import compute_rms, compute_crest_factor, compute_stereo_width, compute_stereo_imbalance, compute_barkspectrum, compute_log_spread

def compute_log_rms(x: torch.Tensor, **kwargs):
    """Compute root mean square energy.

    Args:
        x: (bs, 1, seq_len)

    Returns:
        rms: (bs, )
    """
    rms=compute_rms(x)
    return 20 * torch.log10(rms.clamp(min=1e-8))

import loudness

def compute_loudness(x: torch.Tensor, sample_rate=44100):
    lufs_out=torch.zeros((x.shape[0], x.shape[1]), device=x.device)
    for b in range(B):
        x_i=x[b].cpu().numpy().T
        lufs_in=loudness.integrated_loudness(x_i, sample_rate)
        lufs_out[b] = torch.tensor(lufs_in, device=x.device)
    
    return lufs_out

class AudioFeatureLoss(torch.nn.Module):
    def __init__(
        self,
        weights: List[float],
        sample_rate: int,
    ) -> None:
        """Compute loss using a set of differentiable audio features.

        Args:
            weights: weights for each feature
            sample_rate: sample rate of audio
            stem_separation: whether to compute loss on stems or mix

        Based on features proposed in:

        Man, B. D., et al.
        "An analysis and evaluation of audio features for multitrack music mixtures."
        (2014).

        """
        super().__init__()
        self.weights = weights
        self.sample_rate = sample_rate
        self.sources_list = ["mix"]
        self.source_weights = [1.0]

        self.transforms = [
            compute_rms,
            compute_crest_factor,
            compute_log_spread,
            compute_stereo_width,
            compute_stereo_imbalance,
            compute_barkspectrum,
        ]

        assert len(self.transforms) == len(weights)

    def forward(self, input: torch.Tensor, target: torch.Tensor):
        losses = {}

        # reshape for example stem dim
        input_stems = input.unsqueeze(1)
        target_stems = target.unsqueeze(1)

        n_stems = input_stems.shape[1]

        # iterate over each stem compute loss for each transform
        for stem_idx in range(n_stems):
            input_stem = input_stems[:, stem_idx, ...]
            target_stem = target_stems[:, stem_idx, ...]

            for transform, weight in zip(self.transforms, self.weights):
                transform_name = "_".join(transform.__name__.split("_")[1:])
                key = f"{self.sources_list[stem_idx]}-{transform_name}"
                input_transform = transform(input_stem, sample_rate=self.sample_rate)
                target_transform = transform(target_stem, sample_rate=self.sample_rate)
                val = torch.nn.functional.mse_loss(input_transform, target_transform)
                losses[key] = weight * val * self.source_weights[stem_idx]

        return losses

def get_AF(x: torch.Tensor):
    """Get audio features from a tensor."""
    rms = compute_log_rms(x, sample_rate=sr)
    crest_factor = compute_crest_factor(x, sample_rate=sr)
    log_spread= compute_log_spread(x, sample_rate=sr)
    stereo_width = compute_stereo_width(x, sample_rate=sr)
    stereo_imbalance = compute_stereo_imbalance(x, sample_rate=sr)

    return rms, crest_factor, log_spread, stereo_width, stereo_imbalance

#af_loss= AudioFeatureLoss(
#    weights=[0.1, 0.001, 1.0, 1.0, 0.1],
#    sample_rate=sr,
#).to(device)
#
#
x=dry_segment.expand(-1,2,-1).to(device)
y=wet_segment.to(device)
#
#losses = af_loss(x, y)

features=get_AF(y)

# %%
import numpy as np
from datasets.tency_mastering_multitrack_random import TencyMastering_Test
import omegaconf    

normalize_params=omegaconf.OmegaConf.create(
    {
    "normalize_mode": "rms_dry",
    #"loudness_dry": -18.0,  # Target loudness for dry tracks
    "rms_dry": -25.0
    }
)
dataset_val= TencyMastering_Test(
  mode= "train",
  segment_length= 525312,
  fs= 44100,
  stereo= True,
  tracks= "all",
  num_tracks= 50,
  path_csv= "/data5/eloi/TencyMastering/PANNs_country_pop/train_split.csv",
  normalize_params=normalize_params,
  num_examples= -1, #use all examples
  RMS_threshold_dB= -40.0,
  seed= 42
)

val_loader = torch.utils.data.DataLoader(dataset=dataset_val, batch_size=1, num_workers=1)  # Use a lambda function to keep the original structure
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# -1 num_examples
# 50it [18:51, 22.63s/it]
# test_samples 7100 num_examples -1 num_skips 0

# %%
def compute_loudness(x: torch.Tensor, sample_rate=44100):
    B, C, T = x.shape
    lufs_out=torch.zeros((x.shape[0], x.shape[1]), device=x.device)
    for b in range(B):
        x_i=x[b].cpu().numpy().T + 1e-6
        lufs_in=loudness.integrated_loudness(x_i, sample_rate)
        lufs_out[b] = torch.tensor(lufs_in, device=x.device)
    
    return lufs_out

def get_AF(x: torch.Tensor):
    """Get audio features from a tensor."""
    loudness = compute_loudness(x, sample_rate=sr)
    crest_factor = compute_crest_factor(x, sample_rate=sr)
    log_spread= compute_log_spread(x, sample_rate=sr)
    stereo_width = compute_stereo_width(x, sample_rate=sr)
    stereo_imbalance = compute_stereo_imbalance(x, sample_rate=sr)

    return loudness, crest_factor, log_spread, stereo_width, stereo_imbalance

features={}
num_iterations=1000
for i, (x, y) in enumerate(val_loader):

    if i >= num_iterations:
        break

    y=y.to(device)

    AF= get_AF(y)

    #check that there is no NaN or Inf in AF
    try:
        for af in AF:
            if torch.isnan(af).any() or torch.isinf(af).any():
                raise ValueError("NaN or Inf found in audio features")
    except ValueError as e:
        print(f"Error in iteration {i}: {e}")
        continue

    print(AF)
    if i==0:
        for j, af in enumerate(AF):
            features[j]=[]
            features[j].append(af.cpu().numpy())

    else:
        for j, af in enumerate(AF):
            features[j].append(af.cpu().numpy())




#take the mean of each feature and the std
features_mean = {}
features_std = {}

for key, value in features.items():
    print(f"Feature {key}: {len(value)} samples")
    features_mean[key] = np.mean(value, axis=0)
    features_std[key] = np.std(value, axis=0)
# Out:
# (tensor([[-18.9472, -18.9472]], device='cuda:0'), tensor([[15.2208, 15.4792]], device='cuda:0'), tensor([[-23.1845, -22.8997]], device='cuda:0'), tensor([0.0396], device='cuda:0'), tensor([0.0050], device='cuda:0'))
# (tensor([[-14.6372, -14.6372]], device='cuda:0'), tensor([[18.2267, 17.5565]], device='cuda:0'), tensor([[-43.7256, -43.6388]], device='cuda:0'), tensor([0.1230], device='cuda:0'), tensor([-0.0001], device='cuda:0'))
# (tensor([[-19.7144, -19.7144]], device='cuda:0'), tensor([[21.3269, 21.4871]], device='cuda:0'), tensor([[-11.5512, -10.6673]], device='cuda:0'), tensor([0.0706], device='cuda:0'), tensor([-0.0323], device='cuda:0'))
# (tensor([[-19.8179, -19.8179]], device='cuda:0'), tensor([[10.2042, 10.2042]], device='cuda:0'), tensor([[-8.4387, -8.4387]], device='cuda:0'), tensor([0.], device='cuda:0'), tensor([0.], device='cuda:0'))
# (tensor([[-15.4821, -15.4821]], device='cuda:0'), tensor([[21.8226, 21.2081]], device='cuda:0'), tensor([[-92.1364, -92.3869]], device='cuda:0'), tensor([0.0343], device='cuda:0'), tensor([0.0157], device='cuda:0'))
# (tensor([[-20.8303, -20.8303]], device='cuda:0'), tensor([[17.7668, 17.2548]], device='cuda:0'), tensor([[-8.4511, -8.6819]], device='cuda:0'), tensor([0.0833], device='cuda:0'), tensor([0.1980], device='cuda:0'))
# (tensor([[-17.9763, -17.9763]], device='cuda:0'), tensor([[21.6817, 21.6025]], device='cuda:0'), tensor([[-12.6548, -13.3560]], device='cuda:0'), tensor([0.4330], device='cuda:0'), tensor([0.0085], device='cuda:0'))
# Error in iteration 7: NaN or Inf found in audio features
# (tensor([[-31.8008, -31.8008]], device='cuda:0'), tensor([[24.0707, 23.1399]], device='cuda:0'), tensor([[-10.0796,  -9.6809]], device='cuda:0'), tensor([0.0653], device='cuda:0'), tensor([0.2761], device='cuda:0'))
# (tensor([[-22.2759, -22.2759]], device='cuda:0'), tensor([[17.7085, 18.8257]], device='cuda:0'), tensor([[-31.6537, -30.2271]], device='cuda:0'), tensor([0.0879], device='cuda:0'), tensor([-0.1208], device='cuda:0'))
# (tensor([[-20.8418, -20.8418]], device='cuda:0'), tensor([[14.9875, 14.9263]], device='cuda:0'), tensor([[-29.8376, -29.8455]], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0017], device='cuda:0'))
# (tensor([[-19.4510, -19.4510]], device='cuda:0'), tensor([[14.8887, 14.6065]], device='cuda:0'), tensor([[-6.0872, -5.9516]], device='cuda:0'), tensor([0.6016], device='cuda:0'), tensor([0.2694], device='cuda:0'))
# (tensor([[-22.4218, -22.4218]], device='cuda:0'), tensor([[21.5356, 20.4218]], device='cuda:0'), tensor([[-33.6656, -33.3550]], device='cuda:0'), tensor([0.0502], device='cuda:0'), tensor([-0.0301], device='cuda:0'))
# (tensor([[-18.3738, -18.3738]], device='cuda:0'), tensor([[16.0006, 16.7721]], device='cuda:0'), tensor([[-14.1850, -15.4481]], device='cuda:0'), tensor([0.1320], device='cuda:0'), tensor([0.4538], device='cuda:0'))
# (tensor([[-17.8720, -17.8720]], device='cuda:0'), tensor([[19.2243, 18.7150]], device='cuda:0'), tensor([[-13.2043, -14.2156]], device='cuda:0'), tensor([0.0547], device='cuda:0'), tensor([0.0244], device='cuda:0'))
# (tensor([[-28.4972, -28.4972]], device='cuda:0'), tensor([[20.9454, 23.9950]], device='cuda:0'), tensor([[-59.7039, -60.1946]], device='cuda:0'), tensor([0.2323], device='cuda:0'), tensor([0.1610], device='cuda:0'))
# (tensor([[-12.6761, -12.6761]], device='cuda:0'), tensor([[15.7135, 15.1702]], device='cuda:0'), tensor([[-73.5538, -73.4213]], device='cuda:0'), tensor([0.0258], device='cuda:0'), tensor([-0.0083], device='cuda:0'))
# (tensor([[-18.5023, -18.5023]], device='cuda:0'), tensor([[18.8381, 18.7461]], device='cuda:0'), tensor([[-14.8576, -14.8807]], device='cuda:0'), tensor([0.0510], device='cuda:0'), tensor([-0.0290], device='cuda:0'))
# (tensor([[-21.6182, -21.6182]], device='cuda:0'), tensor([[13.6412, 13.4432]], device='cuda:0'), tensor([[-6.1168, -6.0564]], device='cuda:0'), tensor([0.0365], device='cuda:0'), tensor([-0.0467], device='cuda:0'))
# (tensor([[-21.0185, -21.0185]], device='cuda:0'), tensor([[14.3409, 14.8371]], device='cuda:0'), tensor([[-6.0048, -5.9825]], device='cuda:0'), tensor([0.8838], device='cuda:0'), tensor([0.0758], device='cuda:0'))
# (tensor([[-28.6763, -28.6763]], device='cuda:0'), tensor([[12.1493, 12.5158]], device='cuda:0'), tensor([[-5.5730, -5.6388]], device='cuda:0'), tensor([0.0333], device='cuda:0'), tensor([-0.0562], device='cuda:0'))
# (tensor([[-19.9862, -19.9862]], device='cuda:0'), tensor([[17.9875, 18.0961]], device='cuda:0'), tensor([[-30.1350, -30.2492]], device='cuda:0'), tensor([0.0034], device='cuda:0'), tensor([-0.0034], device='cuda:0'))
# (tensor([[-26.7832, -26.7832]], device='cuda:0'), tensor([[11.2667, 11.3159]], device='cuda:0'), tensor([[-5.2307, -5.1592]], device='cuda:0'), tensor([0.0083], device='cuda:0'), tensor([-0.0135], device='cuda:0'))
# (tensor([[-22.6219, -22.6219]], device='cuda:0'), tensor([[23.8700, 22.5798]], device='cuda:0'), tensor([[-45.6380, -46.0225]], device='cuda:0'), tensor([0.0825], device='cuda:0'), tensor([0.1511], device='cuda:0'))
# (tensor([[-30.2880, -30.2880]], device='cuda:0'), tensor([[17.9060, 18.2555]], device='cuda:0'), tensor([[-6.3228, -6.3769]], device='cuda:0'), tensor([0.7343], device='cuda:0'), tensor([0.9882], device='cuda:0'))
# (tensor([[-19.5803, -19.5803]], device='cuda:0'), tensor([[13.5931, 13.5773]], device='cuda:0'), tensor([[-16.4193, -16.4138]], device='cuda:0'), tensor([0.0131], device='cuda:0'), tensor([0.0064], device='cuda:0'))
# (tensor([[-24.6149, -24.6149]], device='cuda:0'), tensor([[12.8345, 13.2170]], device='cuda:0'), tensor([[-5.5543, -5.6171]], device='cuda:0'), tensor([0.3138], device='cuda:0'), tensor([-0.0909], device='cuda:0'))
# (tensor([[-24.2457, -24.2457]], device='cuda:0'), tensor([[16.2192, 16.4612]], device='cuda:0'), tensor([[-6.4380, -6.3810]], device='cuda:0'), tensor([0.0147], device='cuda:0'), tensor([-0.0079], device='cuda:0'))
# (tensor([[-20.4548, -20.4548]], device='cuda:0'), tensor([[26.3679, 26.2009]], device='cuda:0'), tensor([[-56.4245, -57.1228]], device='cuda:0'), tensor([0.0886], device='cuda:0'), tensor([0.0777], device='cuda:0'))
# (tensor([[-31.7336, -31.7336]], device='cuda:0'), tensor([[18.8037, 18.8054]], device='cuda:0'), tensor([[-33.0660, -30.6416]], device='cuda:0'), tensor([0.0626], device='cuda:0'), tensor([-0.4710], device='cuda:0'))
# (tensor([[-13.5625, -13.5625]], device='cuda:0'), tensor([[16.3020, 16.4328]], device='cuda:0'), tensor([[-33.6237, -33.6051]], device='cuda:0'), tensor([5.8045e-05], device='cuda:0'), tensor([0.0098], device='cuda:0'))
# (tensor([[-22.3644, -22.3644]], device='cuda:0'), tensor([[12.6100, 12.5368]], device='cuda:0'), tensor([[-7.6641, -7.6191]], device='cuda:0'), tensor([0.7197], device='cuda:0'), tensor([0.9866], device='cuda:0'))
# (tensor([[-16.1213, -16.1213]], device='cuda:0'), tensor([[11.8154, 12.3250]], device='cuda:0'), tensor([[-43.3620, -43.4839]], device='cuda:0'), tensor([0.0027], device='cuda:0'), tensor([-0.0221], device='cuda:0'))
# (tensor([[-13.2400, -13.2400]], device='cuda:0'), tensor([[19.8189, 20.2366]], device='cuda:0'), tensor([[-46.0772, -47.5170]], device='cuda:0'), tensor([0.0182], device='cuda:0'), tensor([-0.0015], device='cuda:0'))
# (tensor([[-17.6281, -17.6281]], device='cuda:0'), tensor([[17.3237, 15.7924]], device='cuda:0'), tensor([[-10.7570,  -7.8270]], device='cuda:0'), tensor([0.1498], device='cuda:0'), tensor([0.2133], device='cuda:0'))
# (tensor([[-25.9942, -25.9942]], device='cuda:0'), tensor([[19.8551, 17.6105]], device='cuda:0'), tensor([[-6.8884, -6.8444]], device='cuda:0'), tensor([0.2793], device='cuda:0'), tensor([0.3230], device='cuda:0'))
# (tensor([[-26.5947, -26.5947]], device='cuda:0'), tensor([[20.2848, 20.2039]], device='cuda:0'), tensor([[-15.0681, -13.9910]], device='cuda:0'), tensor([0.2145], device='cuda:0'), tensor([-0.0569], device='cuda:0'))
# (tensor([[-20.2659, -20.2659]], device='cuda:0'), tensor([[15.4223, 16.2730]], device='cuda:0'), tensor([[-28.7947, -21.4857]], device='cuda:0'), tensor([0.7160], device='cuda:0'), tensor([-0.9862], device='cuda:0'))
# (tensor([[-26.3968, -26.3968]], device='cuda:0'), tensor([[22.6718, 22.5977]], device='cuda:0'), tensor([[-51.8691, -54.6109]], device='cuda:0'), tensor([0.1567], device='cuda:0'), tensor([0.6841], device='cuda:0'))
# (tensor([[-21.6724, -21.6724]], device='cuda:0'), tensor([[23.2341, 23.6915]], device='cuda:0'), tensor([[-14.7750, -14.0521]], device='cuda:0'), tensor([0.1050], device='cuda:0'), tensor([-0.0277], device='cuda:0'))
# (tensor([[-16.4800, -16.4800]], device='cuda:0'), tensor([[17.0262, 18.6105]], device='cuda:0'), tensor([[-11.4167, -11.2261]], device='cuda:0'), tensor([0.1608], device='cuda:0'), tensor([0.0176], device='cuda:0'))
# (tensor([[-16.8026, -16.8026]], device='cuda:0'), tensor([[18.6940, 18.3207]], device='cuda:0'), tensor([[-13.5405, -14.2344]], device='cuda:0'), tensor([0.0475], device='cuda:0'), tensor([0.1084], device='cuda:0'))
# (tensor([[-23.7071, -23.7071]], device='cuda:0'), tensor([[21.8536, 20.0949]], device='cuda:0'), tensor([[-49.4672, -50.1052]], device='cuda:0'), tensor([0.8030], device='cuda:0'), tensor([0.2022], device='cuda:0'))
# (tensor([[-22.9406, -22.9406]], device='cuda:0'), tensor([[13.1876, 12.1435]], device='cuda:0'), tensor([[-9.5202, -8.9982]], device='cuda:0'), tensor([0.0859], device='cuda:0'), tensor([-0.4488], device='cuda:0'))
# (tensor([[-17.8792, -17.8792]], device='cuda:0'), tensor([[25.2036, 24.8601]], device='cuda:0'), tensor([[-46.9971, -47.8862]], device='cuda:0'), tensor([0.8097], device='cuda:0'), tensor([0.0835], device='cuda:0'))
# (tensor([[-23.7829, -23.7829]], device='cuda:0'), tensor([[28.5193, 27.1033]], device='cuda:0'), tensor([[-35.8934, -35.5704]], device='cuda:0'), tensor([0.2520], device='cuda:0'), tensor([0.0676], device='cuda:0'))
# (tensor([[-25.5081, -25.5081]], device='cuda:0'), tensor([[26.7886, 27.3913]], device='cuda:0'), tensor([[-45.8589, -46.1370]], device='cuda:0'), tensor([0.0354], device='cuda:0'), tensor([-0.0582], device='cuda:0'))
# (tensor([[-25.7097, -25.7097]], device='cuda:0'), tensor([[17.0463, 17.3379]], device='cuda:0'), tensor([[-13.1096, -13.2415]], device='cuda:0'), tensor([0.3114], device='cuda:0'), tensor([0.0094], device='cuda:0'))
# (tensor([[-26.5172, -26.5172]], device='cuda:0'), tensor([[18.0838, 18.0831]], device='cuda:0'), tensor([[-6.1497, -6.1507]], device='cuda:0'), tensor([1.3918e-06], device='cuda:0'), tensor([-0.0004], device='cuda:0'))
# (tensor([[-28.1232, -28.1232]], device='cuda:0'), tensor([[20.0827, 20.0679]], device='cuda:0'), tensor([[-32.6946, -32.6051]], device='cuda:0'), tensor([0.0329], device='cuda:0'), tensor([-0.0237], device='cuda:0'))
# (tensor([[-29.2343, -29.2343]], device='cuda:0'), tensor([[25.5031, 25.7706]], device='cuda:0'), tensor([[-25.4294, -29.8082]], device='cuda:0'), tensor([0.0186], device='cuda:0'), tensor([-0.0288], device='cuda:0'))
# (tensor([[-19.8731, -19.8731]], device='cuda:0'), tensor([[25.2633, 25.2264]], device='cuda:0'), tensor([[-40.1987, -40.0170]], device='cuda:0'), tensor([0.1185], device='cuda:0'), tensor([0.0290], device='cuda:0'))
# (tensor([[-16.5498, -16.5498]], device='cuda:0'), tensor([[9.7285, 9.8029]], device='cuda:0'), tensor([[-4.6420, -4.6328]], device='cuda:0'), tensor([5.7295e-05], device='cuda:0'), tensor([-0.0025], device='cuda:0'))
# (tensor([[-19.8187, -19.8187]], device='cuda:0'), tensor([[13.6233, 14.7585]], device='cuda:0'), tensor([[-6.5026, -6.1515]], device='cuda:0'), tensor([0.2524], device='cuda:0'), tensor([-0.0212], device='cuda:0'))
# (tensor([[-19.9804, -19.9804]], device='cuda:0'), tensor([[9.2391, 9.2387]], device='cuda:0'), tensor([[-6.5344, -6.5341]], device='cuda:0'), tensor([6.3547e-09], device='cuda:0'), tensor([-1.0246e-06], device='cuda:0'))
# (tensor([[-24.4581, -24.4581]], device='cuda:0'), tensor([[18.2230, 18.3325]], device='cuda:0'), tensor([[-6.0662, -6.2004]], device='cuda:0'), tensor([0.0107], device='cuda:0'), tensor([-0.0356], device='cuda:0'))
# (tensor([[-19.9522, -19.9522]], device='cuda:0'), tensor([[26.7104, 25.7860]], device='cuda:0'), tensor([[-98.0495, -97.8942]], device='cuda:0'), tensor([0.1514], device='cuda:0'), tensor([-0.0151], device='cuda:0'))
# (tensor([[-22.1344, -22.1344]], device='cuda:0'), tensor([[16.1231, 16.4573]], device='cuda:0'), tensor([[-9.6818, -9.6026]], device='cuda:0'), tensor([0.0043], device='cuda:0'), tensor([0.0337], device='cuda:0'))
# (tensor([[-22.5405, -22.5405]], device='cuda:0'), tensor([[18.5638, 18.3323]], device='cuda:0'), tensor([[-52.0634, -52.0433]], device='cuda:0'), tensor([0.0089], device='cuda:0'), tensor([0.0176], device='cuda:0'))
# (tensor([[-34.0899, -34.0899]], device='cuda:0'), tensor([[16.0548, 16.5542]], device='cuda:0'), tensor([[-6.6782, -6.7782]], device='cuda:0'), tensor([0.0576], device='cuda:0'), tensor([0.3007], device='cuda:0'))
# (tensor([[-19.5535, -19.5535]], device='cuda:0'), tensor([[21.2575, 21.2276]], device='cuda:0'), tensor([[-102.6519, -102.6278]], device='cuda:0'), tensor([0.6750], device='cuda:0'), tensor([0.0487], device='cuda:0'))
# (tensor([[-20.0231, -20.0231]], device='cuda:0'), tensor([[10.0649, 10.0659]], device='cuda:0'), tensor([[-19.6632, -19.6681]], device='cuda:0'), tensor([7.5320e-09], device='cuda:0'), tensor([-4.8327e-07], device='cuda:0'))
# (tensor([[-29.5744, -29.5744]], device='cuda:0'), tensor([[16.3280, 17.0154]], device='cuda:0'), tensor([[-10.5263, -10.4132]], device='cuda:0'), tensor([0.0325], device='cuda:0'), tensor([-0.1357], device='cuda:0'))
# (tensor([[-30.7854, -30.7854]], device='cuda:0'), tensor([[14.4690, 14.3054]], device='cuda:0'), tensor([[-14.4930, -14.4307]], device='cuda:0'), tensor([0.0077], device='cuda:0'), tensor([-0.0013], device='cuda:0'))
# (tensor([[-21.0862, -21.0862]], device='cuda:0'), tensor([[15.0548, 14.0501]], device='cuda:0'), tensor([[-6.2169, -6.6749]], device='cuda:0'), tensor([0.5004], device='cuda:0'), tensor([0.8765], device='cuda:0'))
# (tensor([[-13.8656, -13.8656]], device='cuda:0'), tensor([[13.9609, 14.1864]], device='cuda:0'), tensor([[-5.8790, -6.3311]], device='cuda:0'), tensor([0.0848], device='cuda:0'), tensor([-0.3891], device='cuda:0'))
# (tensor([[-23.4217, -23.4217]], device='cuda:0'), tensor([[15.3795, 17.0106]], device='cuda:0'), tensor([[-9.6845, -9.8403]], device='cuda:0'), tensor([0.9216], device='cuda:0'), tensor([0.0367], device='cuda:0'))
# (tensor([[-22.8956, -22.8956]], device='cuda:0'), tensor([[21.5948, 20.6200]], device='cuda:0'), tensor([[-15.0159, -17.0591]], device='cuda:0'), tensor([0.1686], device='cuda:0'), tensor([-0.0060], device='cuda:0'))
# (tensor([[-22.3871, -22.3871]], device='cuda:0'), tensor([[12.5102, 12.4258]], device='cuda:0'), tensor([[-5.8480, -5.7578]], device='cuda:0'), tensor([0.0042], device='cuda:0'), tensor([-0.0155], device='cuda:0'))
# (tensor([[-17.2555, -17.2555]], device='cuda:0'), tensor([[18.0141, 18.2859]], device='cuda:0'), tensor([[-15.0283, -14.6866]], device='cuda:0'), tensor([0.0701], device='cuda:0'), tensor([-0.0392], device='cuda:0'))
# (tensor([[-18.6601, -18.6601]], device='cuda:0'), tensor([[19.0971, 18.6856]], device='cuda:0'), tensor([[-12.7900, -11.1279]], device='cuda:0'), tensor([0.0582], device='cuda:0'), tensor([-0.0018], device='cuda:0'))
# (tensor([[-17.7345, -17.7345]], device='cuda:0'), tensor([[19.7059, 19.7229]], device='cuda:0'), tensor([[-34.1321, -34.1371]], device='cuda:0'), tensor([0.0017], device='cuda:0'), tensor([-0.0088], device='cuda:0'))
# (tensor([[-19.5896, -19.5896]], device='cuda:0'), tensor([[10.6830, 11.0478]], device='cuda:0'), tensor([[-28.6893, -28.5129]], device='cuda:0'), tensor([0.0108], device='cuda:0'), tensor([-0.0729], device='cuda:0'))
# (tensor([[-25.9184, -25.9184]], device='cuda:0'), tensor([[15.3182, 16.2216]], device='cuda:0'), tensor([[-11.3480,  -9.7784]], device='cuda:0'), tensor([0.4248], device='cuda:0'), tensor([-0.5361], device='cuda:0'))
# (tensor([[-25.0121, -25.0121]], device='cuda:0'), tensor([[12.9647, 14.1386]], device='cuda:0'), tensor([[-13.8577, -13.6875]], device='cuda:0'), tensor([0.9065], device='cuda:0'), tensor([-0.2530], device='cuda:0'))
# (tensor([[-18.4307, -18.4307]], device='cuda:0'), tensor([[10.7175,  9.8644]], device='cuda:0'), tensor([[-6.9146, -5.8118]], device='cuda:0'), tensor([0.9333], device='cuda:0'), tensor([0.0749], device='cuda:0'))
# (tensor([[-29.5541, -29.5541]], device='cuda:0'), tensor([[20.0249, 19.5942]], device='cuda:0'), tensor([[-14.6385, -15.0136]], device='cuda:0'), tensor([0.3998], device='cuda:0'), tensor([0.2084], device='cuda:0'))
# (tensor([[-15.5504, -15.5504]], device='cuda:0'), tensor([[17.1812, 16.9683]], device='cuda:0'), tensor([[-14.6325, -14.5787]], device='cuda:0'), tensor([0.0318], device='cuda:0'), tensor([-0.0030], device='cuda:0'))
# (tensor([[-16.1343, -16.1343]], device='cuda:0'), tensor([[17.0417, 17.5780]], device='cuda:0'), tensor([[-10.5487, -10.3643]], device='cuda:0'), tensor([0.1586], device='cuda:0'), tensor([0.0146], device='cuda:0'))
# (tensor([[-21.5556, -21.5556]], device='cuda:0'), tensor([[15.1153, 16.0133]], device='cuda:0'), tensor([[-6.7636, -6.3144]], device='cuda:0'), tensor([0.7162], device='cuda:0'), tensor([-0.0487], device='cuda:0'))
# (tensor([[-18.8300, -18.8300]], device='cuda:0'), tensor([[14.4974, 14.1192]], device='cuda:0'), tensor([[-10.0246, -10.1221]], device='cuda:0'), tensor([0.0114], device='cuda:0'), tensor([-0.0008], device='cuda:0'))
# (tensor([[-19.8248, -19.8248]], device='cuda:0'), tensor([[11.1694, 11.5001]], device='cuda:0'), tensor([[-27.3480, -27.2849]], device='cuda:0'), tensor([0.0159], device='cuda:0'), tensor([-0.0040], device='cuda:0'))
# (tensor([[-15.9984, -15.9984]], device='cuda:0'), tensor([[14.0350, 14.0350]], device='cuda:0'), tensor([[-26.9398, -26.9392]], device='cuda:0'), tensor([1.3811e-12], device='cuda:0'), tensor([0.], device='cuda:0'))
# (tensor([[-16.6553, -16.6553]], device='cuda:0'), tensor([[15.2599, 14.7842]], device='cuda:0'), tensor([[-69.8154, -69.6910]], device='cuda:0'), tensor([0.0563], device='cuda:0'), tensor([-0.0144], device='cuda:0'))
# (tensor([[-26.8413, -26.8413]], device='cuda:0'), tensor([[17.2070, 18.1798]], device='cuda:0'), tensor([[-49.6174, -37.9772]], device='cuda:0'), tensor([0.9497], device='cuda:0'), tensor([-0.9979], device='cuda:0'))
# (tensor([[-22.2409, -22.2409]], device='cuda:0'), tensor([[16.3254, 17.7151]], device='cuda:0'), tensor([[-8.5478, -9.0141]], device='cuda:0'), tensor([0.3341], device='cuda:0'), tensor([-0.2397], device='cuda:0'))
# (tensor([[-14.6938, -14.6938]], device='cuda:0'), tensor([[17.4549, 16.5983]], device='cuda:0'), tensor([[-11.9553, -11.1042]], device='cuda:0'), tensor([0.2270], device='cuda:0'), tensor([0.0281], device='cuda:0'))
# (tensor([[-22.0217, -22.0217]], device='cuda:0'), tensor([[15.0983, 14.3547]], device='cuda:0'), tensor([[-7.3683, -7.6912]], device='cuda:0'), tensor([0.7202], device='cuda:0'), tensor([0.9867], device='cuda:0'))
# (tensor([[-30.1594, -30.1594]], device='cuda:0'), tensor([[18.4547, 18.5046]], device='cuda:0'), tensor([[-7.5951, -7.6310]], device='cuda:0'), tensor([0.0020], device='cuda:0'), tensor([-0.0119], device='cuda:0'))
# (tensor([[-16.8931, -16.8931]], device='cuda:0'), tensor([[26.0134, 26.7597]], device='cuda:0'), tensor([[-105.9208, -105.6758]], device='cuda:0'), tensor([0.0594], device='cuda:0'), tensor([-0.0916], device='cuda:0'))
# (tensor([[-18.7074, -18.7074]], device='cuda:0'), tensor([[22.2135, 21.6511]], device='cuda:0'), tensor([[-20.4310, -18.8686]], device='cuda:0'), tensor([0.0252], device='cuda:0'), tensor([0.0533], device='cuda:0'))
# (tensor([[-21.2226, -21.2226]], device='cuda:0'), tensor([[14.3054, 13.7092]], device='cuda:0'), tensor([[-5.4471, -5.4126]], device='cuda:0'), tensor([0.5447], device='cuda:0'), tensor([-0.9473], device='cuda:0'))
# (tensor([[-63.7855, -63.7855]], device='cuda:0'), tensor([[21.2332, 20.6413]], device='cuda:0'), tensor([[-46.3389, -43.3475]], device='cuda:0'), tensor([0.2359], device='cuda:0'), tensor([-0.4074], device='cuda:0'))
# (tensor([[-22.3102, -22.3102]], device='cuda:0'), tensor([[27.0859, 27.9473]], device='cuda:0'), tensor([[-46.8226, -47.1661]], device='cuda:0'), tensor([0.4542], device='cuda:0'), tensor([-0.0099], device='cuda:0'))
# (tensor([[-21.9536, -21.9536]], device='cuda:0'), tensor([[20.6578, 20.8623]], device='cuda:0'), tensor([[-40.4753, -40.5122]], device='cuda:0'), tensor([0.0286], device='cuda:0'), tensor([0.0033], device='cuda:0'))
# (tensor([[-19.9440, -19.9440]], device='cuda:0'), tensor([[14.0404, 15.9428]], device='cuda:0'), tensor([[-7.5198, -7.5403]], device='cuda:0'), tensor([0.1823], device='cuda:0'), tensor([-0.0426], device='cuda:0'))
# (tensor([[-19.7752, -19.7752]], device='cuda:0'), tensor([[19.0298, 18.7281]], device='cuda:0'), tensor([[-21.6987, -21.6927]], device='cuda:0'), tensor([0.0060], device='cuda:0'), tensor([-0.0301], device='cuda:0'))
# (tensor([[-21.6843, -21.6843]], device='cuda:0'), tensor([[16.8934, 17.2476]], device='cuda:0'), tensor([[-20.4536, -20.6713]], device='cuda:0'), tensor([0.1755], device='cuda:0'), tensor([-0.0142], device='cuda:0'))
# (tensor([[-20.8883, -20.8883]], device='cuda:0'), tensor([[19.2612, 19.2333]], device='cuda:0'), tensor([[-10.4406, -10.0956]], device='cuda:0'), tensor([0.0427], device='cuda:0'), tensor([-0.1806], device='cuda:0'))
# (tensor([[-21.5171, -21.5171]], device='cuda:0'), tensor([[14.1129, 13.9422]], device='cuda:0'), tensor([[-5.8061, -5.7774]], device='cuda:0'), tensor([0.3544], device='cuda:0'), tensor([0.3775], device='cuda:0'))
# (tensor([[-20.3359, -20.3359]], device='cuda:0'), tensor([[16.5727, 16.0619]], device='cuda:0'), tensor([[-27.4548, -38.4325]], device='cuda:0'), tensor([0.7165], device='cuda:0'), tensor([0.9863], device='cuda:0'))
# (tensor([[-20.2144, -20.2144]], device='cuda:0'), tensor([[19.3304, 19.8444]], device='cuda:0'), tensor([[-13.4062, -13.5006]], device='cuda:0'), tensor([0.0825], device='cuda:0'), tensor([0.0100], device='cuda:0'))
# (tensor([[-22.0451, -22.0451]], device='cuda:0'), tensor([[13.5262, 13.9885]], device='cuda:0'), tensor([[-18.0359, -18.2313]], device='cuda:0'), tensor([0.4873], device='cuda:0'), tensor([0.0821], device='cuda:0'))
# (tensor([[-23.6837, -23.6837]], device='cuda:0'), tensor([[13.4403, 14.8031]], device='cuda:0'), tensor([[-10.5681, -11.4726]], device='cuda:0'), tensor([0.6881], device='cuda:0'), tensor([0.9812], device='cuda:0'))
# (tensor([[-16.3403, -16.3403]], device='cuda:0'), tensor([[19.2230, 19.3237]], device='cuda:0'), tensor([[-9.6216, -8.3416]], device='cuda:0'), tensor([0.0818], device='cuda:0'), tensor([-0.0081], device='cuda:0'))
# (tensor([[-16.9852, -16.9852]], device='cuda:0'), tensor([[17.3235, 17.3014]], device='cuda:0'), tensor([[-14.3355, -14.1465]], device='cuda:0'), tensor([0.0177], device='cuda:0'), tensor([0.0012], device='cuda:0'))
# (tensor([[-22.1374, -22.1374]], device='cuda:0'), tensor([[22.7661, 22.0286]], device='cuda:0'), tensor([[-41.5972, -41.9324]], device='cuda:0'), tensor([0.3009], device='cuda:0'), tensor([0.0646], device='cuda:0'))
# (tensor([[-13.2910, -13.2910]], device='cuda:0'), tensor([[14.7591, 14.6704]], device='cuda:0'), tensor([[-11.8753, -11.8858]], device='cuda:0'), tensor([6.1898e-05], device='cuda:0'), tensor([0.0102], device='cuda:0'))
# (tensor([[-25.5055, -25.5055]], device='cuda:0'), tensor([[18.3313, 18.6065]], device='cuda:0'), tensor([[-6.4289, -6.4501]], device='cuda:0'), tensor([0.0114], device='cuda:0'), tensor([-0.0382], device='cuda:0'))
# (tensor([[-23.0760, -23.0760]], device='cuda:0'), tensor([[16.1280, 16.5697]], device='cuda:0'), tensor([[-13.4088, -13.3774]], device='cuda:0'), tensor([0.0172], device='cuda:0'), tensor([0.0166], device='cuda:0'))
# (tensor([[-24.1362, -24.1362]], device='cuda:0'), tensor([[16.2114, 18.5044]], device='cuda:0'), tensor([[-16.3109, -18.6879]], device='cuda:0'), tensor([0.6444], device='cuda:0'), tensor([-0.0776], device='cuda:0'))
# (tensor([[-13.5566, -13.5566]], device='cuda:0'), tensor([[13.6889, 13.8425]], device='cuda:0'), tensor([[-7.9661, -7.9778]], device='cuda:0'), tensor([0.0034], device='cuda:0'), tensor([-0.0109], device='cuda:0'))
# (tensor([[-17.2303, -17.2303]], device='cuda:0'), tensor([[16.0658, 15.2695]], device='cuda:0'), tensor([[-17.8749, -18.1066]], device='cuda:0'), tensor([0.2682], device='cuda:0'), tensor([0.0687], device='cuda:0'))
# (tensor([[-22.2872, -22.2872]], device='cuda:0'), tensor([[15.0874, 14.0677]], device='cuda:0'), tensor([[-13.5559, -13.1876]], device='cuda:0'), tensor([0.2915], device='cuda:0'), tensor([-0.0891], device='cuda:0'))
# (tensor([[-20.8083, -20.8083]], device='cuda:0'), tensor([[19.2078, 19.2075]], device='cuda:0'), tensor([[-11.5814, -11.5822]], device='cuda:0'), tensor([1.1997e-08], device='cuda:0'), tensor([-8.6885e-07], device='cuda:0'))
# (tensor([[-20.4182, -20.4182]], device='cuda:0'), tensor([[14.3043, 14.4312]], device='cuda:0'), tensor([[-7.9014, -7.9254]], device='cuda:0'), tensor([0.2185], device='cuda:0'), tensor([0.0093], device='cuda:0'))
# (tensor([[-24.8136, -24.8136]], device='cuda:0'), tensor([[19.5156, 18.9574]], device='cuda:0'), tensor([[-27.3084, -27.5524]], device='cuda:0'), tensor([0.1345], device='cuda:0'), tensor([0.0272], device='cuda:0'))
# (tensor([[-24.6039, -24.6039]], device='cuda:0'), tensor([[20.8455, 20.6114]], device='cuda:0'), tensor([[-12.5583, -12.8434]], device='cuda:0'), tensor([0.0027], device='cuda:0'), tensor([0.0147], device='cuda:0'))
# (tensor([[-20.7204, -20.7204]], device='cuda:0'), tensor([[19.4349, 17.7835]], device='cuda:0'), tensor([[-43.9959, -43.5543]], device='cuda:0'), tensor([0.3085], device='cuda:0'), tensor([-0.2518], device='cuda:0'))
# (tensor([[-16.8569, -16.8569]], device='cuda:0'), tensor([[13.4591, 13.2304]], device='cuda:0'), tensor([[-6.0900, -5.9379]], device='cuda:0'), tensor([0.0032], device='cuda:0'), tensor([0.0068], device='cuda:0'))
# (tensor([[-20.7633, -20.7633]], device='cuda:0'), tensor([[16.3245, 14.1403]], device='cuda:0'), tensor([[-12.4821, -12.4608]], device='cuda:0'), tensor([0.6619], device='cuda:0'), tensor([-0.1159], device='cuda:0'))
# (tensor([[-16.6036, -16.6036]], device='cuda:0'), tensor([[13.8774, 13.3001]], device='cuda:0'), tensor([[-5.7717, -5.5995]], device='cuda:0'), tensor([0.2077], device='cuda:0'), tensor([0.0100], device='cuda:0'))
# (tensor([[-18.0777, -18.0777]], device='cuda:0'), tensor([[17.8512, 16.8707]], device='cuda:0'), tensor([[-20.9936, -20.9293]], device='cuda:0'), tensor([0.1322], device='cuda:0'), tensor([-0.0409], device='cuda:0'))
# (tensor([[-17.0746, -17.0746]], device='cuda:0'), tensor([[18.0621, 17.8472]], device='cuda:0'), tensor([[-14.4284, -14.2901]], device='cuda:0'), tensor([0.0178], device='cuda:0'), tensor([0.0199], device='cuda:0'))
# (tensor([[-18.1087, -18.1087]], device='cuda:0'), tensor([[16.8439, 17.4542]], device='cuda:0'), tensor([[-7.8724, -8.5888]], device='cuda:0'), tensor([0.1680], device='cuda:0'), tensor([-0.0790], device='cuda:0'))
# (tensor([[-23.3200, -23.3200]], device='cuda:0'), tensor([[25.2673, 23.2584]], device='cuda:0'), tensor([[-11.6855, -12.1594]], device='cuda:0'), tensor([0.3760], device='cuda:0'), tensor([-0.0451], device='cuda:0'))
# (tensor([[-23.7286, -23.7286]], device='cuda:0'), tensor([[14.5364, 15.3715]], device='cuda:0'), tensor([[-5.3665, -5.4296]], device='cuda:0'), tensor([0.7541], device='cuda:0'), tensor([0.9885], device='cuda:0'))
# (tensor([[-22.5468, -22.5468]], device='cuda:0'), tensor([[16.0840, 17.1096]], device='cuda:0'), tensor([[-9.3468, -8.5869]], device='cuda:0'), tensor([0.0949], device='cuda:0'), tensor([-0.1715], device='cuda:0'))
# (tensor([[-24.5097, -24.5097]], device='cuda:0'), tensor([[21.0765, 20.8939]], device='cuda:0'), tensor([[-20.1138, -15.8495]], device='cuda:0'), tensor([0.4461], device='cuda:0'), tensor([-0.8878], device='cuda:0'))
# (tensor([[-18.6418, -18.6418]], device='cuda:0'), tensor([[12.8479, 12.0308]], device='cuda:0'), tensor([[-5.2082, -5.0488]], device='cuda:0'), tensor([0.0345], device='cuda:0'), tensor([0.0290], device='cuda:0'))
# (tensor([[-19.9913, -19.9913]], device='cuda:0'), tensor([[18.0801, 18.0037]], device='cuda:0'), tensor([[-16.2438, -16.0881]], device='cuda:0'), tensor([0.0094], device='cuda:0'), tensor([0.0137], device='cuda:0'))
# (tensor([[-17.8736, -17.8736]], device='cuda:0'), tensor([[11.8591, 12.0125]], device='cuda:0'), tensor([[-5.7237, -5.7223]], device='cuda:0'), tensor([0.0903], device='cuda:0'), tensor([-0.2338], device='cuda:0'))
# (tensor([[-22.6050, -22.6050]], device='cuda:0'), tensor([[24.5384, 24.3650]], device='cuda:0'), tensor([[-40.0697, -40.4021]], device='cuda:0'), tensor([0.0029], device='cuda:0'), tensor([0.0163], device='cuda:0'))
# (tensor([[-23.9812, -23.9812]], device='cuda:0'), tensor([[22.1141, 23.8339]], device='cuda:0'), tensor([[-17.7772, -17.4808]], device='cuda:0'), tensor([0.3334], device='cuda:0'), tensor([-0.4272], device='cuda:0'))
# (tensor([[-24.8328, -24.8328]], device='cuda:0'), tensor([[16.2664, 16.5243]], device='cuda:0'), tensor([[-8.8187, -8.1470]], device='cuda:0'), tensor([1.0786], device='cuda:0'), tensor([-0.1722], device='cuda:0'))
# (tensor([[-28.4330, -28.4330]], device='cuda:0'), tensor([[15.5531, 14.2316]], device='cuda:0'), tensor([[-6.3197, -5.9178]], device='cuda:0'), tensor([0.5175], device='cuda:0'), tensor([-0.8779], device='cuda:0'))
# (tensor([[-31.2670, -31.2670]], device='cuda:0'), tensor([[17.4146, 13.0453]], device='cuda:0'), tensor([[-6.5657, -6.4580]], device='cuda:0'), tensor([0.3311], device='cuda:0'), tensor([0.0373], device='cuda:0'))
# (tensor([[-16.7003, -16.7003]], device='cuda:0'), tensor([[17.0174, 17.1075]], device='cuda:0'), tensor([[-60.4478, -60.5274]], device='cuda:0'), tensor([0.0073], device='cuda:0'), tensor([0.0016], device='cuda:0'))
# (tensor([[-18.8365, -18.8365]], device='cuda:0'), tensor([[21.0640, 19.9378]], device='cuda:0'), tensor([[-23.4264, -23.1347]], device='cuda:0'), tensor([0.0615], device='cuda:0'), tensor([-0.0048], device='cuda:0'))
# (tensor([[-18.7278, -18.7278]], device='cuda:0'), tensor([[17.6096, 17.2529]], device='cuda:0'), tensor([[-14.1243, -14.5595]], device='cuda:0'), tensor([0.0270], device='cuda:0'), tensor([-0.0217], device='cuda:0'))
# (tensor([[-22.7952, -22.7952]], device='cuda:0'), tensor([[14.2209, 14.1688]], device='cuda:0'), tensor([[-5.8546, -5.7485]], device='cuda:0'), tensor([0.2919], device='cuda:0'), tensor([0.5824], device='cuda:0'))
# (tensor([[-17.0276, -17.0276]], device='cuda:0'), tensor([[17.3485, 16.9260]], device='cuda:0'), tensor([[-18.3378, -18.3091]], device='cuda:0'), tensor([0.1569], device='cuda:0'), tensor([0.0431], device='cuda:0'))
# (tensor([[-16.3073, -16.3073]], device='cuda:0'), tensor([[9.6509, 9.6691]], device='cuda:0'), tensor([[-4.7425, -4.7355]], device='cuda:0'), tensor([6.4076e-05], device='cuda:0'), tensor([-0.0028], device='cuda:0'))
# (tensor([[-18.4704, -18.4704]], device='cuda:0'), tensor([[19.4790, 19.7331]], device='cuda:0'), tensor([[-13.2434, -14.4788]], device='cuda:0'), tensor([0.0334], device='cuda:0'), tensor([-0.0089], device='cuda:0'))
# (tensor([[-23.8941, -23.8941]], device='cuda:0'), tensor([[15.9615, 16.2709]], device='cuda:0'), tensor([[-11.1648, -10.4601]], device='cuda:0'), tensor([0.1876], device='cuda:0'), tensor([-0.3624], device='cuda:0'))
# (tensor([[-32.6146, -32.6146]], device='cuda:0'), tensor([[14.7439, 16.3676]], device='cuda:0'), tensor([[-12.8041, -11.4010]], device='cuda:0'), tensor([0.0781], device='cuda:0'), tensor([-0.1475], device='cuda:0'))
# (tensor([[-14.1950, -14.1950]], device='cuda:0'), tensor([[17.0937, 17.1749]], device='cuda:0'), tensor([[-13.6707, -12.7311]], device='cuda:0'), tensor([0.2297], device='cuda:0'), tensor([0.0168], device='cuda:0'))
# (tensor([[-17.1935, -17.1935]], device='cuda:0'), tensor([[16.9049, 17.2708]], device='cuda:0'), tensor([[-63.1057, -62.6643]], device='cuda:0'), tensor([0.0512], device='cuda:0'), tensor([0.0260], device='cuda:0'))
# (tensor([[-19.9364, -19.9364]], device='cuda:0'), tensor([[12.5823, 16.5120]], device='cuda:0'), tensor([[-8.4806, -5.8422]], device='cuda:0'), tensor([0.3814], device='cuda:0'), tensor([-0.2068], device='cuda:0'))
# (tensor([[-28.7700, -28.7700]], device='cuda:0'), tensor([[19.4299, 18.5723]], device='cuda:0'), tensor([[-38.0738, -38.3427]], device='cuda:0'), tensor([0.0739], device='cuda:0'), tensor([0.0279], device='cuda:0'))
# (tensor([[-25.0749, -25.0749]], device='cuda:0'), tensor([[18.5831, 17.5507]], device='cuda:0'), tensor([[-34.0018, -34.2250]], device='cuda:0'), tensor([0.2320], device='cuda:0'), tensor([0.0237], device='cuda:0'))
# (tensor([[-30.4012, -30.4012]], device='cuda:0'), tensor([[21.3636, 21.4909]], device='cuda:0'), tensor([[-18.9418, -19.5934]], device='cuda:0'), tensor([0.0253], device='cuda:0'), tensor([0.0047], device='cuda:0'))
# (tensor([[-17.4540, -17.4540]], device='cuda:0'), tensor([[23.0422, 21.4582]], device='cuda:0'), tensor([[-28.6185, -28.0069]], device='cuda:0'), tensor([1.6314], device='cuda:0'), tensor([-0.0533], device='cuda:0'))
# (tensor([[-18.0438, -18.0438]], device='cuda:0'), tensor([[19.3909, 21.2310]], device='cuda:0'), tensor([[-39.4126, -39.0533]], device='cuda:0'), tensor([0.6595], device='cuda:0'), tensor([-0.0519], device='cuda:0'))
# (tensor([[-23.1304, -23.1304]], device='cuda:0'), tensor([[17.8810, 15.3830]], device='cuda:0'), tensor([[-6.6771, -7.2918]], device='cuda:0'), tensor([0.2988], device='cuda:0'), tensor([0.0240], device='cuda:0'))
# (tensor([[-19.1768, -19.1768]], device='cuda:0'), tensor([[19.0384, 18.1884]], device='cuda:0'), tensor([[-10.7373, -10.6937]], device='cuda:0'), tensor([0.5233], device='cuda:0'), tensor([-0.1667], device='cuda:0'))
# (tensor([[-24.6049, -24.6049]], device='cuda:0'), tensor([[16.8659, 17.2364]], device='cuda:0'), tensor([[-7.2950, -7.6700]], device='cuda:0'), tensor([0.8993], device='cuda:0'), tensor([0.0981], device='cuda:0'))
# (tensor([[-15.8809, -15.8809]], device='cuda:0'), tensor([[13.3785, 13.4080]], device='cuda:0'), tensor([[-17.8204, -18.2234]], device='cuda:0'), tensor([0.9766], device='cuda:0'), tensor([-0.2309], device='cuda:0'))
# (tensor([[-25.4867, -25.4867]], device='cuda:0'), tensor([[13.1846, 13.5842]], device='cuda:0'), tensor([[-5.8461, -5.7412]], device='cuda:0'), tensor([0.5012], device='cuda:0'), tensor([-0.2936], device='cuda:0'))
# (tensor([[-19.9167, -19.9167]], device='cuda:0'), tensor([[9.2737, 9.2734]], device='cuda:0'), tensor([[-6.1702, -6.1695]], device='cuda:0'), tensor([6.1725e-09], device='cuda:0'), tensor([-5.2485e-07], device='cuda:0'))
# (tensor([[-25.2546, -25.2546]], device='cuda:0'), tensor([[18.3092, 16.7232]], device='cuda:0'), tensor([[-8.1541, -8.9115]], device='cuda:0'), tensor([1.0013], device='cuda:0'), tensor([0.4036], device='cuda:0'))
# (tensor([[-19.7924, -19.7924]], device='cuda:0'), tensor([[15.5827, 15.5827]], device='cuda:0'), tensor([[-25.3281, -24.9259]], device='cuda:0'), tensor([0.0498], device='cuda:0'), tensor([-0.4250], device='cuda:0'))
# (tensor([[-23.6914, -23.6914]], device='cuda:0'), tensor([[13.2543, 15.0112]], device='cuda:0'), tensor([[-7.2043, -6.7833]], device='cuda:0'), tensor([0.6468], device='cuda:0'), tensor([-0.5328], device='cuda:0'))
# (tensor([[-20.5338, -20.5338]], device='cuda:0'), tensor([[19.5749, 19.5745]], device='cuda:0'), tensor([[-14.8270, -14.8268]], device='cuda:0'), tensor([1.5580e-08], device='cuda:0'), tensor([1.9621e-06], device='cuda:0'))
# (tensor([[-27.1391, -27.1391]], device='cuda:0'), tensor([[21.4978, 22.5155]], device='cuda:0'), tensor([[-12.2273, -10.0101]], device='cuda:0'), tensor([0.0706], device='cuda:0'), tensor([0.0540], device='cuda:0'))
# (tensor([[-19.0961, -19.0961]], device='cuda:0'), tensor([[19.3107, 19.3931]], device='cuda:0'), tensor([[-43.9921, -43.6902]], device='cuda:0'), tensor([0.7260], device='cuda:0'), tensor([0.0697], device='cuda:0'))
# (tensor([[-17.0617, -17.0617]], device='cuda:0'), tensor([[19.4528, 19.7373]], device='cuda:0'), tensor([[-11.5420, -10.2711]], device='cuda:0'), tensor([0.0836], device='cuda:0'), tensor([-0.0349], device='cuda:0'))
# (tensor([[-18.7240, -18.7240]], device='cuda:0'), tensor([[14.8209, 15.5301]], device='cuda:0'), tensor([[-41.4632, -41.4079]], device='cuda:0'), tensor([0.0214], device='cuda:0'), tensor([-0.0342], device='cuda:0'))
# (tensor([[-16.8199, -16.8199]], device='cuda:0'), tensor([[9.9253, 9.9434]], device='cuda:0'), tensor([[-8.4390, -8.4419]], device='cuda:0'), tensor([7.3908e-05], device='cuda:0'), tensor([0.0055], device='cuda:0'))
# (tensor([[-24.4834, -24.4834]], device='cuda:0'), tensor([[15.5216, 16.7761]], device='cuda:0'), tensor([[-8.7343, -8.4076]], device='cuda:0'), tensor([1.3852], device='cuda:0'), tensor([-0.1936], device='cuda:0'))
# (tensor([[-21.7785, -21.7785]], device='cuda:0'), tensor([[17.2385, 17.6235]], device='cuda:0'), tensor([[-7.1875, -7.8408]], device='cuda:0'), tensor([0.2016], device='cuda:0'), tensor([-0.6901], device='cuda:0'))
# (tensor([[-19.7031, -19.7031]], device='cuda:0'), tensor([[13.9593, 13.6636]], device='cuda:0'), tensor([[-21.7797, -21.5921]], device='cuda:0'), tensor([0.5968], device='cuda:0'), tensor([-0.0756], device='cuda:0'))
# (tensor([[-18.3273, -18.3273]], device='cuda:0'), tensor([[13.1210, 14.7876]], device='cuda:0'), tensor([[-10.0659,  -9.6760]], device='cuda:0'), tensor([0.1184], device='cuda:0'), tensor([-0.2167], device='cuda:0'))
# (tensor([[-24.3733, -24.3733]], device='cuda:0'), tensor([[16.2760, 14.3872]], device='cuda:0'), tensor([[-8.5754, -6.4834]], device='cuda:0'), tensor([1.0840], device='cuda:0'), tensor([-0.9938], device='cuda:0'))
# (tensor([[-15.3700, -15.3700]], device='cuda:0'), tensor([[12.8297, 13.5717]], device='cuda:0'), tensor([[-5.9957, -6.1016]], device='cuda:0'), tensor([0.0198], device='cuda:0'), tensor([-0.0785], device='cuda:0'))
# (tensor([[-19.3395, -19.3395]], device='cuda:0'), tensor([[18.7136, 18.2925]], device='cuda:0'), tensor([[-10.0591, -10.5111]], device='cuda:0'), tensor([0.0606], device='cuda:0'), tensor([-0.0300], device='cuda:0'))
# (tensor([[-26.9724, -26.9724]], device='cuda:0'), tensor([[19.1888, 17.2149]], device='cuda:0'), tensor([[-7.3008, -7.4615]], device='cuda:0'), tensor([0.2733], device='cuda:0'), tensor([0.4572], device='cuda:0'))
# (tensor([[-12.2277, -12.2277]], device='cuda:0'), tensor([[17.4058, 17.3394]], device='cuda:0'), tensor([[-31.6850, -31.6659]], device='cuda:0'), tensor([0.0349], device='cuda:0'), tensor([0.0094], device='cuda:0'))
# (tensor([[-16.0746, -16.0746]], device='cuda:0'), tensor([[19.7741, 19.5677]], device='cuda:0'), tensor([[-9.7009, -9.9558]], device='cuda:0'), tensor([0.4792], device='cuda:0'), tensor([0.0279], device='cuda:0'))
# (tensor([[-14.6105, -14.6105]], device='cuda:0'), tensor([[14.6968, 14.7580]], device='cuda:0'), tensor([[-35.6564, -35.2277]], device='cuda:0'), tensor([0.0269], device='cuda:0'), tensor([-0.0186], device='cuda:0'))
# (tensor([[-28.6304, -28.6304]], device='cuda:0'), tensor([[24.1463, 26.3979]], device='cuda:0'), tensor([[-21.7499, -18.1526]], device='cuda:0'), tensor([1.4020], device='cuda:0'), tensor([-0.3433], device='cuda:0'))
# (tensor([[-20.9767, -20.9767]], device='cuda:0'), tensor([[11.6675, 11.6675]], device='cuda:0'), tensor([[-11.2147, -11.2118]], device='cuda:0'), tensor([1.0471e-11], device='cuda:0'), tensor([0.], device='cuda:0'))
# (tensor([[-27.0585, -27.0585]], device='cuda:0'), tensor([[22.8260, 22.1779]], device='cuda:0'), tensor([[-94.5385, -89.3831]], device='cuda:0'), tensor([0.1679], device='cuda:0'), tensor([-0.6168], device='cuda:0'))
# (tensor([[-27.1278, -27.1278]], device='cuda:0'), tensor([[19.5097, 20.2675]], device='cuda:0'), tensor([[-56.0086, -56.2972]], device='cuda:0'), tensor([0.8017], device='cuda:0'), tensor([0.0087], device='cuda:0'))
# (tensor([[-13.5952, -13.5952]], device='cuda:0'), tensor([[19.0213, 18.7449]], device='cuda:0'), tensor([[-77.7074, -77.7697]], device='cuda:0'), tensor([0.0267], device='cuda:0'), tensor([0.0105], device='cuda:0'))
# (tensor([[-21.9086, -21.9086]], device='cuda:0'), tensor([[15.2405, 15.1941]], device='cuda:0'), tensor([[-18.4909, -18.5160]], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0008], device='cuda:0'))
# (tensor([[-18.8704, -18.8704]], device='cuda:0'), tensor([[13.8525, 13.1578]], device='cuda:0'), tensor([[-29.1457, -33.3973]], device='cuda:0'), tensor([0.3615], device='cuda:0'), tensor([0.8831], device='cuda:0'))
# (tensor([[-23.4826, -23.4826]], device='cuda:0'), tensor([[18.6376, 18.6234]], device='cuda:0'), tensor([[-14.5772, -18.4305]], device='cuda:0'), tensor([0.3446], device='cuda:0'), tensor([0.8579], device='cuda:0'))
# (tensor([[-18.9599, -18.9599]], device='cuda:0'), tensor([[20.7378, 20.4962]], device='cuda:0'), tensor([[-17.6580, -18.1087]], device='cuda:0'), tensor([0.0037], device='cuda:0'), tensor([0.0279], device='cuda:0'))
# (tensor([[-24.8702, -24.8702]], device='cuda:0'), tensor([[17.7786, 14.9514]], device='cuda:0'), tensor([[-31.7009, -24.8454]], device='cuda:0'), tensor([1.0302], device='cuda:0'), tensor([-0.9956], device='cuda:0'))
# (tensor([[-21.0805, -21.0805]], device='cuda:0'), tensor([[20.1415, 21.4434]], device='cuda:0'), tensor([[-89.5522, -89.2100]], device='cuda:0'), tensor([0.4622], device='cuda:0'), tensor([-0.1229], device='cuda:0'))
# (tensor([[-18.4041, -18.4041]], device='cuda:0'), tensor([[13.9431, 13.8486]], device='cuda:0'), tensor([[-6.9187, -6.6562]], device='cuda:0'), tensor([0.0523], device='cuda:0'), tensor([-0.2996], device='cuda:0'))
# (tensor([[-20.6256, -20.6256]], device='cuda:0'), tensor([[19.9696, 19.8195]], device='cuda:0'), tensor([[-14.4866, -14.2704]], device='cuda:0'), tensor([0.0822], device='cuda:0'), tensor([0.0182], device='cuda:0'))
# (tensor([[-16.0995, -16.0995]], device='cuda:0'), tensor([[16.0288, 16.0540]], device='cuda:0'), tensor([[-28.1256, -28.0326]], device='cuda:0'), tensor([0.0134], device='cuda:0'), tensor([-0.0006], device='cuda:0'))
# (tensor([[-23.2716, -23.2716]], device='cuda:0'), tensor([[24.9543, 23.4186]], device='cuda:0'), tensor([[-11.6724, -12.1235]], device='cuda:0'), tensor([0.3764], device='cuda:0'), tensor([-0.0452], device='cuda:0'))
# (tensor([[-22.1800, -22.1800]], device='cuda:0'), tensor([[23.8907, 23.6227]], device='cuda:0'), tensor([[-62.1567, -63.5923]], device='cuda:0'), tensor([0.0925], device='cuda:0'), tensor([0.5015], device='cuda:0'))
# (tensor([[-21.5022, -21.5022]], device='cuda:0'), tensor([[12.2985, 11.9373]], device='cuda:0'), tensor([[-34.7069, -34.6807]], device='cuda:0'), tensor([0.0025], device='cuda:0'), tensor([0.0061], device='cuda:0'))
# (tensor([[-16.8509, -16.8509]], device='cuda:0'), tensor([[12.7512, 13.5877]], device='cuda:0'), tensor([[-7.0661, -6.8965]], device='cuda:0'), tensor([0.0620], device='cuda:0'), tensor([-0.0082], device='cuda:0'))
# (tensor([[-18.8566, -18.8566]], device='cuda:0'), tensor([[20.2458, 19.9388]], device='cuda:0'), tensor([[-16.9636, -17.5234]], device='cuda:0'), tensor([0.0379], device='cuda:0'), tensor([0.0255], device='cuda:0'))
# (tensor([[-19.7651, -19.7651]], device='cuda:0'), tensor([[12.6310, 12.7060]], device='cuda:0'), tensor([[-9.8316, -9.8598]], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([-0.0101], device='cuda:0'))
# (tensor([[-17.8918, -17.8918]], device='cuda:0'), tensor([[14.9161, 14.9161]], device='cuda:0'), tensor([[-21.1383, -20.8777]], device='cuda:0'), tensor([0.0498], device='cuda:0'), tensor([-0.4250], device='cuda:0'))
# (tensor([[-19.0030, -19.0030]], device='cuda:0'), tensor([[12.1944, 11.7936]], device='cuda:0'), tensor([[-5.5942, -5.5761]], device='cuda:0'), tensor([0.0191], device='cuda:0'), tensor([-0.0186], device='cuda:0'))
# (tensor([[-22.7795, -22.7795]], device='cuda:0'), tensor([[13.3359, 17.1615]], device='cuda:0'), tensor([[-6.7248, -8.4182]], device='cuda:0'), tensor([0.8602], device='cuda:0'), tensor([0.9779], device='cuda:0'))
# (tensor([[-26.0028, -26.0028]], device='cuda:0'), tensor([[14.6337, 14.5329]], device='cuda:0'), tensor([[-44.7111, -44.1055]], device='cuda:0'), tensor([0.6351], device='cuda:0'), tensor([-0.1848], device='cuda:0'))
# (tensor([[-31.2310, -31.2310]], device='cuda:0'), tensor([[22.5423, 22.4060]], device='cuda:0'), tensor([[-21.5854, -21.8928]], device='cuda:0'), tensor([0.0239], device='cuda:0'), tensor([-0.0022], device='cuda:0'))
# (tensor([[-18.3340, -18.3340]], device='cuda:0'), tensor([[20.2850, 20.1624]], device='cuda:0'), tensor([[-12.2258, -12.4195]], device='cuda:0'), tensor([0.0429], device='cuda:0'), tensor([0.0140], device='cuda:0'))
# (tensor([[-16.8602, -16.8602]], device='cuda:0'), tensor([[15.9119, 15.8021]], device='cuda:0'), tensor([[-10.8739, -10.5156]], device='cuda:0'), tensor([0.0609], device='cuda:0'), tensor([-0.0120], device='cuda:0'))
# (tensor([[-18.7910, -18.7910]], device='cuda:0'), tensor([[17.4192, 15.8813]], device='cuda:0'), tensor([[-21.1159, -23.2264]], device='cuda:0'), tensor([0.1502], device='cuda:0'), tensor([0.4587], device='cuda:0'))
# (tensor([[-15.0444, -15.0444]], device='cuda:0'), tensor([[19.1647, 18.9903]], device='cuda:0'), tensor([[-54.8228, -54.7751]], device='cuda:0'), tensor([0.0024], device='cuda:0'), tensor([-0.0069], device='cuda:0'))
# (tensor([[-19.3054, -19.3054]], device='cuda:0'), tensor([[18.9076, 18.9696]], device='cuda:0'), tensor([[-14.3163, -14.9807]], device='cuda:0'), tensor([0.3642], device='cuda:0'), tensor([0.8186], device='cuda:0'))
# (tensor([[-63.6537, -63.6537]], device='cuda:0'), tensor([[23.0681, 23.6107]], device='cuda:0'), tensor([[-40.6315, -39.3989]], device='cuda:0'), tensor([0.8975], device='cuda:0'), tensor([-0.0444], device='cuda:0'))
# (tensor([[-24.9150, -24.9150]], device='cuda:0'), tensor([[26.5511, 26.8435]], device='cuda:0'), tensor([[-31.6981, -32.4368]], device='cuda:0'), tensor([0.1173], device='cuda:0'), tensor([-0.0029], device='cuda:0'))
# (tensor([[-18.6899, -18.6899]], device='cuda:0'), tensor([[12.1988, 12.1909]], device='cuda:0'), tensor([[-5.2448, -5.2446]], device='cuda:0'), tensor([4.2010e-06], device='cuda:0'), tensor([-1.1973e-05], device='cuda:0'))
# (tensor([[-12.8940, -12.8940]], device='cuda:0'), tensor([[15.6151, 15.9058]], device='cuda:0'), tensor([[-10.2583, -10.5680]], device='cuda:0'), tensor([0.0179], device='cuda:0'), tensor([-0.0013], device='cuda:0'))
# (tensor([[-18.9881, -18.9881]], device='cuda:0'), tensor([[13.6076, 13.9074]], device='cuda:0'), tensor([[-6.6736, -6.5531]], device='cuda:0'), tensor([0.0554], device='cuda:0'), tensor([-0.3171], device='cuda:0'))
# (tensor([[-27.2045, -27.2045]], device='cuda:0'), tensor([[15.7736, 15.6188]], device='cuda:0'), tensor([[-9.7864, -9.8366]], device='cuda:0'), tensor([0.0074], device='cuda:0'), tensor([0.0199], device='cuda:0'))
# (tensor([[-16.2283, -16.2283]], device='cuda:0'), tensor([[14.8291, 14.8951]], device='cuda:0'), tensor([[-6.8554, -6.7944]], device='cuda:0'), tensor([0.0571], device='cuda:0'), tensor([-0.0493], device='cuda:0'))
# (tensor([[-29.0870, -29.0870]], device='cuda:0'), tensor([[22.4566, 21.0567]], device='cuda:0'), tensor([[-10.4613, -10.7039]], device='cuda:0'), tensor([0.2766], device='cuda:0'), tensor([0.0600], device='cuda:0'))
# (tensor([[-21.8425, -21.8425]], device='cuda:0'), tensor([[13.3814, 14.8650]], device='cuda:0'), tensor([[-6.9254, -8.2099]], device='cuda:0'), tensor([0.1914], device='cuda:0'), tensor([0.6576], device='cuda:0'))
# (tensor([[-24.4154, -24.4154]], device='cuda:0'), tensor([[16.6309, 15.6482]], device='cuda:0'), tensor([[-6.1652, -5.8976]], device='cuda:0'), tensor([1.2700], device='cuda:0'), tensor([-0.0242], device='cuda:0'))
# (tensor([[-14.1507, -14.1507]], device='cuda:0'), tensor([[16.8859, 16.3605]], device='cuda:0'), tensor([[-7.1246, -7.0771]], device='cuda:0'), tensor([1.8738], device='cuda:0'), tensor([0.0252], device='cuda:0'))
# (tensor([[-22.4290, -22.4290]], device='cuda:0'), tensor([[19.1108, 19.0771]], device='cuda:0'), tensor([[-22.9095, -22.9147]], device='cuda:0'), tensor([0.0451], device='cuda:0'), tensor([-0.2033], device='cuda:0'))
# ...
# (tensor([[-15.1323, -15.1323]], device='cuda:0'), tensor([[13.5671, 13.6502]], device='cuda:0'), tensor([[-12.9647, -13.4067]], device='cuda:0'), tensor([0.6487], device='cuda:0'), tensor([0.0712], device='cuda:0'))
# (tensor([[-32.0365, -32.0365]], device='cuda:0'), tensor([[18.0225, 17.9455]], device='cuda:0'), tensor([[-28.3260, -28.3861]], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0023], device='cuda:0'))
# (tensor([[-19.3833, -19.3833]], device='cuda:0'), tensor([[15.4949, 17.9571]], device='cuda:0'), tensor([[-28.1848, -28.0601]], device='cuda:0'), tensor([0.5542], device='cuda:0'), tensor([0.0031], device='cuda:0'))
# (tensor([[-12.3998, -12.3998]], device='cuda:0'), tensor([[19.2975, 19.2196]], device='cuda:0'), tensor([[-48.8124, -48.6172]], device='cuda:0'), tensor([0.0311], device='cuda:0'), tensor([-0.0391], device='cuda:0'))
# (tensor([[-11.7689, -11.7689]], device='cuda:0'), tensor([[14.2990, 14.3303]], device='cuda:0'), tensor([[-11.2040, -11.0778]], device='cuda:0'), tensor([0.0299], device='cuda:0'), tensor([0.0035], device='cuda:0'))
# (tensor([[-21.7457, -21.7457]], device='cuda:0'), tensor([[18.1324, 17.0676]], device='cuda:0'), tensor([[-8.8842, -9.1087]], device='cuda:0'), tensor([0.0804], device='cuda:0'), tensor([0.1982], device='cuda:0'))
# (tensor([[-25.7813, -25.7813]], device='cuda:0'), tensor([[20.0527, 21.5814]], device='cuda:0'), tensor([[-15.9391, -14.2072]], device='cuda:0'), tensor([0.3779], device='cuda:0'), tensor([-0.7197], device='cuda:0'))
# (tensor([[-24.0294, -24.0294]], device='cuda:0'), tensor([[12.9294, 13.9862]], device='cuda:0'), tensor([[-5.5869, -5.6777]], device='cuda:0'), tensor([0.3822], device='cuda:0'), tensor([0.0303], device='cuda:0'))
# (tensor([[-19.6767, -19.6767]], device='cuda:0'), tensor([[8.1803, 8.7494]], device='cuda:0'), tensor([[-4.6410, -4.6440]], device='cuda:0'), tensor([0.0018], device='cuda:0'), tensor([-0.0014], device='cuda:0'))
# (tensor([[-28.3803, -28.3803]], device='cuda:0'), tensor([[14.7215, 13.3904]], device='cuda:0'), tensor([[-5.7896, -5.7380]], device='cuda:0'), tensor([0.3373], device='cuda:0'), tensor([-0.1887], device='cuda:0'))
# (tensor([[-13.7207, -13.7207]], device='cuda:0'), tensor([[15.4173, 15.6004]], device='cuda:0'), tensor([[-17.9930, -17.3502]], device='cuda:0'), tensor([0.0439], device='cuda:0'), tensor([-0.0041], device='cuda:0'))
# (tensor([[-26.3080, -26.3080]], device='cuda:0'), tensor([[21.0076, 19.6161]], device='cuda:0'), tensor([[-55.3390, -55.9254]], device='cuda:0'), tensor([0.7051], device='cuda:0'), tensor([0.0388], device='cuda:0'))
# (tensor([[-18.4672, -18.4672]], device='cuda:0'), tensor([[12.8787, 12.2911]], device='cuda:0'), tensor([[-33.3497, -32.6810]], device='cuda:0'), tensor([0.0215], device='cuda:0'), tensor([-0.1391], device='cuda:0'))
# (tensor([[-21.1217, -21.1217]], device='cuda:0'), tensor([[13.5963, 15.4658]], device='cuda:0'), tensor([[-6.8507, -6.6982]], device='cuda:0'), tensor([1.3796], device='cuda:0'), tensor([-0.3206], device='cuda:0'))
# (tensor([[-23.4797, -23.4797]], device='cuda:0'), tensor([[16.9858, 16.5872]], device='cuda:0'), tensor([[-25.3031, -25.3806]], device='cuda:0'), tensor([0.0604], device='cuda:0'), tensor([-0.0239], device='cuda:0'))
# (tensor([[-22.9367, -22.9367]], device='cuda:0'), tensor([[18.6830, 18.9703]], device='cuda:0'), tensor([[-27.9157, -31.2008]], device='cuda:0'), tensor([1.0225], device='cuda:0'), tensor([0.9426], device='cuda:0'))
# (tensor([[-19.7757, -19.7757]], device='cuda:0'), tensor([[13.3861, 14.2238]], device='cuda:0'), tensor([[-8.5037, -9.1302]], device='cuda:0'), tensor([0.9793], device='cuda:0'), tensor([-0.0734], device='cuda:0'))
# (tensor([[-19.7605, -19.7605]], device='cuda:0'), tensor([[19.0699, 19.7804]], device='cuda:0'), tensor([[-10.3645, -10.1689]], device='cuda:0'), tensor([0.7525], device='cuda:0'), tensor([-0.3394], device='cuda:0'))
# (tensor([[-15.9802, -15.9802]], device='cuda:0'), tensor([[14.0387, 14.4014]], device='cuda:0'), tensor([[-7.4410, -7.3438]], device='cuda:0'), tensor([0.2644], device='cuda:0'), tensor([-0.0638], device='cuda:0'))
# (tensor([[-25.4952, -25.4952]], device='cuda:0'), tensor([[12.0088, 12.6367]], device='cuda:0'), tensor([[-14.5433, -14.7521]], device='cuda:0'), tensor([0.0927], device='cuda:0'), tensor([-0.0950], device='cuda:0'))
# (tensor([[-24.8587, -24.8587]], device='cuda:0'), tensor([[23.0499, 23.1160]], device='cuda:0'), tensor([[-54.5388, -50.6752]], device='cuda:0'), tensor([0.3884], device='cuda:0'), tensor([-0.5140], device='cuda:0'))
# (tensor([[-36.3698, -36.3698]], device='cuda:0'), tensor([[13.1329, 11.3006]], device='cuda:0'), tensor([[-5.1851, -5.1755]], device='cuda:0'), tensor([0.0736], device='cuda:0'), tensor([0.2936], device='cuda:0'))
# (tensor([[-17.7099, -17.7099]], device='cuda:0'), tensor([[10.5558, 10.5509]], device='cuda:0'), tensor([[-7.6868, -7.6781]], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([-0.0086], device='cuda:0'))
# (tensor([[-21.6756, -21.6756]], device='cuda:0'), tensor([[14.2361, 16.4357]], device='cuda:0'), tensor([[-29.5311, -32.0510]], device='cuda:0'), tensor([1.0023], device='cuda:0'), tensor([-0.9737], device='cuda:0'))
# (tensor([[-16.8421, -16.8421]], device='cuda:0'), tensor([[17.6058, 17.5314]], device='cuda:0'), tensor([[-62.4757, -62.2106]], device='cuda:0'), tensor([0.3891], device='cuda:0'), tensor([-0.0452], device='cuda:0'))
# (tensor([[-20.5162, -20.5162]], device='cuda:0'), tensor([[16.7274, 15.5894]], device='cuda:0'), tensor([[-6.1431, -6.0578]], device='cuda:0'), tensor([0.8535], device='cuda:0'), tensor([0.1102], device='cuda:0'))
# (tensor([[-31.1502, -31.1502]], device='cuda:0'), tensor([[14.2517, 14.2681]], device='cuda:0'), tensor([[-7.7858, -7.7748]], device='cuda:0'), tensor([0.0079], device='cuda:0'), tensor([-0.0002], device='cuda:0'))
# (tensor([[-21.6765, -21.6765]], device='cuda:0'), tensor([[21.6287, 22.6792]], device='cuda:0'), tensor([[-63.9348, -63.7709]], device='cuda:0'), tensor([0.3578], device='cuda:0'), tensor([-0.0472], device='cuda:0'))
# (tensor([[-18.6698, -18.6698]], device='cuda:0'), tensor([[14.6657, 13.9692]], device='cuda:0'), tensor([[-6.1674, -6.1418]], device='cuda:0'), tensor([0.1671], device='cuda:0'), tensor([0.1820], device='cuda:0'))
# (tensor([[-22.0127, -22.0127]], device='cuda:0'), tensor([[14.5114, 14.6576]], device='cuda:0'), tensor([[-16.0037, -15.7185]], device='cuda:0'), tensor([0.2928], device='cuda:0'), tensor([-0.3377], device='cuda:0'))
# (tensor([[-24.9559, -24.9559]], device='cuda:0'), tensor([[18.3760, 18.8417]], device='cuda:0'), tensor([[-30.1731, -29.7490]], device='cuda:0'), tensor([0.2107], device='cuda:0'), tensor([0.0369], device='cuda:0'))
# (tensor([[-23.1069, -23.1069]], device='cuda:0'), tensor([[10.0653, 10.0653]], device='cuda:0'), tensor([[-36.6339, -36.6307]], device='cuda:0'), tensor([1.7756e-11], device='cuda:0'), tensor([8.7789e-08], device='cuda:0'))
# (tensor([[-21.9646, -21.9646]], device='cuda:0'), tensor([[17.5332, 17.7956]], device='cuda:0'), tensor([[-19.1333, -18.9721]], device='cuda:0'), tensor([0.0729], device='cuda:0'), tensor([0.0213], device='cuda:0'))
# (tensor([[-20.8592, -20.8592]], device='cuda:0'), tensor([[19.3455, 20.4604]], device='cuda:0'), tensor([[-25.3692, -28.9985]], device='cuda:0'), tensor([0.2767], device='cuda:0'), tensor([0.7630], device='cuda:0'))
# (tensor([[-31.8521, -31.8521]], device='cuda:0'), tensor([[19.5580, 15.0792]], device='cuda:0'), tensor([[-11.8477, -11.8882]], device='cuda:0'), tensor([0.2819], device='cuda:0'), tensor([0.0456], device='cuda:0'))
# (tensor([[-23.7328, -23.7328]], device='cuda:0'), tensor([[16.9764, 18.3108]], device='cuda:0'), tensor([[-27.1958, -29.0713]], device='cuda:0'), tensor([1.3026], device='cuda:0'), tensor([-0.0100], device='cuda:0'))
# (tensor([[-28.8834, -28.8834]], device='cuda:0'), tensor([[15.6774, 16.0889]], device='cuda:0'), tensor([[-5.9197, -6.0933]], device='cuda:0'), tensor([0.5679], device='cuda:0'), tensor([0.8937], device='cuda:0'))
# (tensor([[-25.1141, -25.1141]], device='cuda:0'), tensor([[13.2792, 15.1054]], device='cuda:0'), tensor([[-28.8577, -22.5898]], device='cuda:0'), tensor([0.5326], device='cuda:0'), tensor([-0.9267], device='cuda:0'))
# (tensor([[-18.7602, -18.7602]], device='cuda:0'), tensor([[21.3270, 21.3881]], device='cuda:0'), tensor([[-15.4764, -14.7881]], device='cuda:0'), tensor([0.0698], device='cuda:0'), tensor([-0.0356], device='cuda:0'))
# (tensor([[-26.2990, -26.2990]], device='cuda:0'), tensor([[12.2322, 12.5219]], device='cuda:0'), tensor([[-22.5704, -22.5928]], device='cuda:0'), tensor([0.1016], device='cuda:0'), tensor([-0.0543], device='cuda:0'))
# (tensor([[-22.4439, -22.4439]], device='cuda:0'), tensor([[27.0094, 26.1753]], device='cuda:0'), tensor([[-15.1671, -14.5088]], device='cuda:0'), tensor([0.0822], device='cuda:0'), tensor([0.0950], device='cuda:0'))
# (tensor([[-18.2750, -18.2750]], device='cuda:0'), tensor([[14.0361, 13.3861]], device='cuda:0'), tensor([[-6.1792, -6.0569]], device='cuda:0'), tensor([0.1979], device='cuda:0'), tensor([-0.6983], device='cuda:0'))
# (tensor([[-20.1625, -20.1625]], device='cuda:0'), tensor([[18.0251, 16.8638]], device='cuda:0'), tensor([[-8.0958, -8.1265]], device='cuda:0'), tensor([0.7626], device='cuda:0'), tensor([-0.0264], device='cuda:0'))
# (tensor([[-17.6644, -17.6644]], device='cuda:0'), tensor([[13.8589, 13.7095]], device='cuda:0'), tensor([[-6.3475, -6.3344]], device='cuda:0'), tensor([0.0541], device='cuda:0'), tensor([-0.2854], device='cuda:0'))
# (tensor([[-12.6427, -12.6427]], device='cuda:0'), tensor([[16.2791, 16.5024]], device='cuda:0'), tensor([[-8.2737, -8.2147]], device='cuda:0'), tensor([0.8814], device='cuda:0'), tensor([-0.0288], device='cuda:0'))
# (tensor([[-20.9188, -20.9188]], device='cuda:0'), tensor([[11.1027, 11.5142]], device='cuda:0'), tensor([[-8.2804, -8.1910]], device='cuda:0'), tensor([0.0166], device='cuda:0'), tensor([0.0269], device='cuda:0'))
# (tensor([[-23.7919, -23.7919]], device='cuda:0'), tensor([[15.6416, 15.4987]], device='cuda:0'), tensor([[-24.1104, -23.5990]], device='cuda:0'), tensor([0.0436], device='cuda:0'), tensor([-0.0997], device='cuda:0'))
# (tensor([[-29.5101, -29.5101]], device='cuda:0'), tensor([[22.4676, 25.4467]], device='cuda:0'), tensor([[-18.5182, -18.5836]], device='cuda:0'), tensor([0.3579], device='cuda:0'), tensor([0.3866], device='cuda:0'))
# (tensor([[-20.5406, -20.5406]], device='cuda:0'), tensor([[23.3989, 25.3620]], device='cuda:0'), tensor([[-65.2907, -65.1611]], device='cuda:0'), tensor([0.2782], device='cuda:0'), tensor([-0.0226], device='cuda:0'))
# (tensor([[-15.3663, -15.3663]], device='cuda:0'), tensor([[14.1849, 14.7638]], device='cuda:0'), tensor([[-12.3075, -12.2445]], device='cuda:0'), tensor([0.2799], device='cuda:0'), tensor([-0.0520], device='cuda:0'))
# (tensor([[-22.3330, -22.3330]], device='cuda:0'), tensor([[14.9295, 16.9438]], device='cuda:0'), tensor([[-8.3400, -8.6137]], device='cuda:0'), tensor([1.0004], device='cuda:0'), tensor([-0.2802], device='cuda:0'))
# (tensor([[-23.4187, -23.4187]], device='cuda:0'), tensor([[19.1442, 19.8202]], device='cuda:0'), tensor([[-6.3576, -6.4657]], device='cuda:0'), tensor([0.0163], device='cuda:0'), tensor([-0.0062], device='cuda:0'))
# (tensor([[-29.4969, -29.4969]], device='cuda:0'), tensor([[19.3756, 19.2712]], device='cuda:0'), tensor([[-26.0546, -25.1997]], device='cuda:0'), tensor([0.4458], device='cuda:0'), tensor([-0.1066], device='cuda:0'))
# (tensor([[-19.5044, -19.5044]], device='cuda:0'), tensor([[13.8377, 12.6500]], device='cuda:0'), tensor([[-19.2337, -17.3528]], device='cuda:0'), tensor([0.7962], device='cuda:0'), tensor([-0.4035], device='cuda:0'))
# (tensor([[-23.8999, -23.8999]], device='cuda:0'), tensor([[24.2939, 21.5985]], device='cuda:0'), tensor([[-14.3953, -14.4076]], device='cuda:0'), tensor([0.1255], device='cuda:0'), tensor([-0.0538], device='cuda:0'))
# (tensor([[-19.9833, -19.9833]], device='cuda:0'), tensor([[14.4288, 15.2030]], device='cuda:0'), tensor([[-48.8802, -47.1358]], device='cuda:0'), tensor([0.0624], device='cuda:0'), tensor([-0.4051], device='cuda:0'))
# (tensor([[-19.1330, -19.1330]], device='cuda:0'), tensor([[21.7405, 22.3177]], device='cuda:0'), tensor([[-42.2220, -41.8527]], device='cuda:0'), tensor([0.0601], device='cuda:0'), tensor([-0.0155], device='cuda:0'))
# (tensor([[-11.8807, -11.8807]], device='cuda:0'), tensor([[ 9.8273, 10.3208]], device='cuda:0'), tensor([[-5.0285, -4.9199]], device='cuda:0'), tensor([0.0682], device='cuda:0'), tensor([-0.0430], device='cuda:0'))
# (tensor([[-27.8050, -27.8050]], device='cuda:0'), tensor([[14.9488, 15.3744]], device='cuda:0'), tensor([[-6.5109, -7.1141]], device='cuda:0'), tensor([0.6222], device='cuda:0'), tensor([-0.0438], device='cuda:0'))
# (tensor([[-24.1453, -24.1453]], device='cuda:0'), tensor([[15.6131, 15.8091]], device='cuda:0'), tensor([[-17.2306, -19.4715]], device='cuda:0'), tensor([2.8213], device='cuda:0'), tensor([-0.0449], device='cuda:0'))
# (tensor([[-18.7634, -18.7634]], device='cuda:0'), tensor([[24.5161, 24.5161]], device='cuda:0'), tensor([[-116.0250, -112.5278]], device='cuda:0'), tensor([0.0498], device='cuda:0'), tensor([-0.4250], device='cuda:0'))
# (tensor([[-18.0039, -18.0039]], device='cuda:0'), tensor([[17.3317, 16.1480]], device='cuda:0'), tensor([[-34.1665, -34.5276]], device='cuda:0'), tensor([0.2202], device='cuda:0'), tensor([0.0759], device='cuda:0'))
# (tensor([[-18.2581, -18.2581]], device='cuda:0'), tensor([[18.7052, 19.3742]], device='cuda:0'), tensor([[-15.5177, -15.2886]], device='cuda:0'), tensor([0.1401], device='cuda:0'), tensor([-0.0538], device='cuda:0'))
# (tensor([[-18.0794, -18.0794]], device='cuda:0'), tensor([[14.6206, 13.9510]], device='cuda:0'), tensor([[-7.7215, -7.4863]], device='cuda:0'), tensor([0.0532], device='cuda:0'), tensor([0.0058], device='cuda:0'))
# (tensor([[-17.3542, -17.3542]], device='cuda:0'), tensor([[14.4848, 14.4848]], device='cuda:0'), tensor([[-60.1287, -63.1711]], device='cuda:0'), tensor([0.1646], device='cuda:0'), tensor([0.6968], device='cuda:0'))
# (tensor([[-15.9527, -15.9527]], device='cuda:0'), tensor([[11.7584, 10.4173]], device='cuda:0'), tensor([[-4.9062, -4.9522]], device='cuda:0'), tensor([0.3152], device='cuda:0'), tensor([0.6686], device='cuda:0'))
# (tensor([[-19.8286, -19.8286]], device='cuda:0'), tensor([[11.8567, 11.8562]], device='cuda:0'), tensor([[-15.7127, -15.5963]], device='cuda:0'), tensor([8.4266e-08], device='cuda:0'), tensor([1.0148e-06], device='cuda:0'))
# (tensor([[-28.3518, -28.3518]], device='cuda:0'), tensor([[26.3063, 17.8647]], device='cuda:0'), tensor([[-18.4979, -16.9571]], device='cuda:0'), tensor([0.2902], device='cuda:0'), tensor([0.6064], device='cuda:0'))
# (tensor([[-21.4247, -21.4247]], device='cuda:0'), tensor([[18.7097, 18.1836]], device='cuda:0'), tensor([[-16.7278, -16.9244]], device='cuda:0'), tensor([0.0215], device='cuda:0'), tensor([0.0199], device='cuda:0'))
# (tensor([[-29.9259, -29.9259]], device='cuda:0'), tensor([[16.7039, 16.1358]], device='cuda:0'), tensor([[-28.3365, -31.2650]], device='cuda:0'), tensor([0.2658], device='cuda:0'), tensor([0.6338], device='cuda:0'))
# Error in iteration 996: NaN or Inf found in audio features
# (tensor([[-24.7256, -24.7256]], device='cuda:0'), tensor([[17.8047, 18.2466]], device='cuda:0'), tensor([[-42.4071, -41.5150]], device='cuda:0'), tensor([0.0607], device='cuda:0'), tensor([-0.0420], device='cuda:0'))
# (tensor([[-27.0456, -27.0456]], device='cuda:0'), tensor([[17.7018, 18.0953]], device='cuda:0'), tensor([[-9.9352, -9.9634]], device='cuda:0'), tensor([0.0076], device='cuda:0'), tensor([-0.0064], device='cuda:0'))
# (tensor([[-13.2362, -13.2362]], device='cuda:0'), tensor([[12.6173, 12.6173]], device='cuda:0'), tensor([[-9.0428, -9.0427]], device='cuda:0'), tensor([6.2450e-13], device='cuda:0'), tensor([0.], device='cuda:0'))
# Feature 0: 994 samples
# Feature 1: 994 samples
# Feature 2: 994 samples
# Feature 3: 994 samples
# Feature 4: 994 samples

# %%
def apply_loud_normalization(x, lufs=-23, sample_rate=44100,device=None):
    """
    x shaPe: (batch_size, channels, time)
    """

    if x.ndim() != 3:
        x_shape= x.shape
        x=x.view(-1, x_shape[-2], x_shape[-1])  # Ensure x is 3D

    B, C, T = x.shape

    if device is None:
        device = x.device

    x_out = torch.zeros_like(x)
    for b in range(B):
        x_i=x[b].cpu().numpy().T
        lufs_in=loudness.integrated_loudness(x_i, sample_rate)

        delta_loudness= lufs - lufs_in
        gain=np.power(10, delta_loudness / 20)  # Convert dB to linear gain

        x_out[b] = torch.tensor(x_i.T * gain, device=device)
    
    if x.ndim() != 3:
        x_out = x_out.view(x_shape)

    return x_out

# %%
wet_segment.shape
wet_segment_norm= apply_loud_normalization(wet_segment, lufs=-23, sample_rate=sr, device=device)
print("wet_segment_norm shape:", wet_segment_norm.shape)
# Out:
# wet_segment_norm shape: torch.Size([1, 2, 524288])

# %%
lufs_out= compute_loudness(wet_segment_norm, sample_rate=sr)
print("Loudness of wet segment after normalization:", lufs_out)
# Out:
# Loudness of wet segment after normalization: tensor([[-23.0090, -23.0090]])

# %%
import math

    
from utils.ITOMaster_loss import compute_log_rms, compute_crest_factor, compute_stereo_width, compute_stereo_imbalance

class AF_RFF_embedding:
    def __init__(self,
                input_dim=6,
                output_dim=64,
                sigma=1.0,
                log_rms_shift=-26.5, #calculated as the mean from the dataset
                log_rms_scale=7.0, #calculated as the std from the dataset
                crest_shift=16.7, #calculated as the mean from the dataset
                crest_scale=6.3,
                stereo_width_shift=0.28,
                stereo_width_scale=0.39,
                stereo_imbalance_shift=0.0,
                stereo_imbalance_scale=0.35,
                device="cpu"
                ):
        """
        Deterministic Fourier feature transformer using fixed cosine-based projection
        """

        self.device = device
        # Ensure output_dim is even and >= 2 * input_dim
        self.output_dim = max(input_dim * 2, output_dim)
        if self.output_dim % 2 != 0:
            self.output_dim += 1
        
        self.input_dim = input_dim
        self.sigma = sigma
        
        # Create deterministic projection matrix
        self.projection = self._create_deterministic_projection(input_dim, self.output_dim // 2, sigma)
        self.projection = self.projection.to(self.device)
        
        # Normalization factor
        self.scale_factor = math.sqrt(2.0 / self.output_dim)

        self.log_rms_shift = log_rms_shift
        self.log_rms_scale = log_rms_scale
        self.crest_shift = crest_shift
        self.crest_scale = crest_scale
        self.stereo_width_shift = stereo_width_shift
        self.stereo_width_scale = stereo_width_scale
        self.stereo_imbalance_shift = stereo_imbalance_shift
        self.stereo_imbalance_scale = stereo_imbalance_scale
    
    def _create_deterministic_projection(self, input_dim, proj_dim, sigma):
        """
        Create a deterministic projection matrix using a cosine basis
        """
        # Cosine-based matrix (like DCT type-II)
        projection = torch.zeros(input_dim, proj_dim)
        for i in range(input_dim):
            for j in range(proj_dim):
                projection[i, j] = math.cos(math.pi * (i + 0.5) * (j + 1) / proj_dim)
        
        return projection * sigma
    
    def encode(self, x):

        log_rms=compute_log_rms(x)
        crest_factor= compute_crest_factor(x)
        stereo_width= compute_stereo_width(x)
        stereo_imbalance= compute_stereo_imbalance(x)


        log_rms_std, crest_factor_std, stereo_width_std, stereo_imbalance_std = self.standardize_features(
            log_rms, crest_factor, stereo_width, stereo_imbalance
        )

        embedding= self.transform(
            log_rms_std, crest_factor_std, stereo_width_std, stereo_imbalance_std
        )

        return embedding, (log_rms, crest_factor, stereo_width, stereo_imbalance)
    
    def decode(self, fourier_features):
        """
        Invert Fourier features back to original feature space
        (approximate due to phase-only reconstruction)
        """
        reconstructed = self.inverse_transform(fourier_features)
        
        # Reshape back to original feature dimensions
        log_rms= reconstructed[:,0:2]
        crest_factor = reconstructed[:,2:4]
        stereo_width = reconstructed[:,4:5]
        stereo_imbalance = reconstructed[:,5:6]

        log_rms, crest_factor, stereo_width, stereo_imbalance = self.destandardize_features(
            log_rms, crest_factor, stereo_width, stereo_imbalance
        )
        
        return log_rms, crest_factor, stereo_width, stereo_imbalance

    def standardize_features(self, log_rms, crest_factor, stereo_width, stereo_imbalance):
        """
        Standardize features using pre-computed mean and std
        """
        log_rms = (log_rms - self.log_rms_shift) / self.log_rms_scale
        crest_factor = (crest_factor - self.crest_shift) / self.crest_scale
        stereo_width = (stereo_width - self.stereo_width_shift) / self.stereo_width_scale
        stereo_imbalance = (stereo_imbalance - self.stereo_imbalance_shift) / self.stereo_imbalance_scale
        
        return log_rms, crest_factor, stereo_width, stereo_imbalance
    
    def destandardize_features(self, log_rms, crest_factor, stereo_width, stereo_imbalance):
        """
        Reverse standardization to get back to original feature space
        """
        log_rms = log_rms * self.log_rms_scale + self.log_rms_shift
        crest_factor = crest_factor * self.crest_scale + self.crest_shift
        stereo_width = stereo_width * self.stereo_width_scale + self.stereo_width_shift
        stereo_imbalance = stereo_imbalance * self.stereo_imbalance_scale + self.stereo_imbalance_shift
        
        return log_rms, crest_factor, stereo_width, stereo_imbalance
        
    def transform(self, log_rms, crest_factor, stereo_width, stereo_imbalance):
        """
        Transform features using the stored projection matrix
        """

        flat_features=torch.cat([log_rms, crest_factor, stereo_width.unsqueeze(-1), stereo_imbalance.unsqueeze(-1)], dim=-1)
        
        # Project and transform
        projected = flat_features @ self.projection
        cos_features = torch.cos(projected)
        sin_features = torch.sin(projected)
        
        # Concatenate and normalize
        return torch.cat([cos_features, sin_features], dim=-1) * self.scale_factor
    
    def inverse_transform(self, fourier_features):
        """
        Invert Fourier features back to original feature space
        (approximate due to phase-only reconstruction)
        """
        # Split into cosine and sine components
        feature_dim = fourier_features.shape[-1] // 2
        cos_features = fourier_features[:, :feature_dim]
        sin_features = fourier_features[:, feature_dim:]
        
        # Denormalize
        cos_features = cos_features / self.scale_factor
        sin_features = sin_features / self.scale_factor
        
        # Compute phase angles
        phases = torch.atan2(sin_features, cos_features)
        
        # Use pseudo-inverse for approximate inversion
        projection_pinv = torch.pinverse(self.projection)
        reconstructed = phases @ projection_pinv
        
        return reconstructed


#AF_embedding = AF_RFF_embedding(device=device, output_dim=128)
AF_embedding = AF_RFF_embedding(device=device)
y= wet_segment.expand(4, 2, -1).to(device)
#print("y shape:", y.shape, y.std(), y.mean(), y.min(), y.max())
embedding, (log_rms, crest_factor, stereo_width, stereo_imbalance) = AF_embedding.encode(y)

print("Embedding shape:", embedding.shape, embedding.std())

log_rms_rec, crest_factor_rec, stereo_width_rec, stereo_imbalance_rec = AF_embedding.decode(embedding)

print("log_rms", log_rms, log_rms_rec )
print("crest_factor", crest_factor, crest_factor_rec)
print("stereo_width", stereo_width, stereo_width_rec)
print("stereo_imbalance", stereo_imbalance, stereo_imbalance_rec)
# Out:
# Embedding shape: torch.Size([4, 64]) tensor(0.1148, device='cuda:0')
